# %% [markdown]
# # 14MBID - TFM
#
# # El parque automovilístico de segunda mano en España. Análisis y estimación del precio de venta
#
# ## Manuel Campoy Naranjo
#
# ### Cuaderno 3
#
# En este cuaderno se hace el análisis descriptivo, prueba y ajuste de modelos para el dataframe df_2mano

# %% [markdown]
# ## Importación de paquetes y librerías. Configuración de rutas y figuras

# %%
# !pip install jcopml --quiet
# !pip install feature_selector --no-binary=:all: --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 KB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 74.6 MB/s eta 0:00:00
#   Building wheel for jcopml (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Running setup.py install for feature_selector ... done

# %%
import time
import os
import io
import pandas as pd
import numpy as np
from numpy import corrcoef, transpose, arange
import seaborn as sns
import plotly.express as px
from google.colab import drive
from functools import reduce
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure
from matplotlib.animation import FuncAnimation

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

#ML

from sklearn import ensemble, preprocessing, metrics
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.model_selection import KFold, cross_val_score, GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from feature_selector import FeatureSelector 
from jcopml.tuning import random_search_params as rsp
from jcopml.pipeline import num_pipe, cat_pipe
from jcopml.utils import save_model, load_model
from jcopml.plot import plot_missing_value
from jcopml.feature_importance import mean_score_decrease
from jcopml.plot import plot_correlation_matrix
from jcopml.plot import plot_actual_vs_prediction, plot_residual
from sklearn.decomposition import PCA
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectFromModel, SelectKBest, RFE,chi2
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression, LogisticRegression, Perceptron, Ridge
from sklearn.linear_model import Lasso, SGDClassifier, LassoCV, MultiTaskLassoCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR, LinearSVR
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.utils import resample,shuffle

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/TFM/Datasets"
# Out:
#  accidentes.xlsx		    'ventas marca 2019.xlsx'
#  autocasion2mano.xlsx		    'ventas marca 2020.xlsx'
#  autocasionnuevos.xlsx		    'ventas marca 2021.xlsx'
#  coches-de-segunda-mano-sample.csv  'ventas marca 2022.xlsx'
#  cochesnetnuevos.xlsx		    'ventas modelo 2015.xlsx'
#  datosBI.xlsx			    'ventas modelo 2016.xlsx'
#  df_2mano_dummies.xlsx		    'ventas modelo 2017.xlsx'
#  df_2mano_pop_dummies.xlsx	    'ventas modelo 2018.xlsx'
#  df_2mano_pop_pre_dummies.xlsx	    'ventas modelo 2019.xlsx'
#  df_2mano_pop_pre.xlsx		    'ventas modelo 2020.xlsx'
#  df_2mano_pop.xlsx		    'ventas modelo 2021.xlsx'
#  df_2mano.xlsx			    'ventas modelo 2022.xlsx'
#  df_provincias.xlsx		    'ventas provincia 2015.xlsx'
#  parque.xlsx			    'ventas provincia 2016.xlsx'
#  pib-capita.xlsx		    'ventas provincia 2017.xlsx'
#  poblacion.xlsx			    'ventas provincia 2018.xlsx'
#  transferencias.xlsx		    'ventas provincia 2019.xlsx'
# 'ventas marca 2015.xlsx'	    'ventas provincia 2020.xlsx'
# 'ventas marca 2016.xlsx'	    'ventas provincia 2021.xlsx'
# 'ventas marca 2017.xlsx'	    'ventas provincia 2022.xlsx'
# 'ventas marca 2018.xlsx'

# %% [markdown]
# Se crea un path de acceso para más comodidad (tanto en local como en Drive)

# %%
#path = '/Users/mcamp/OneDrive/Escritorio/TFM/'
#path = '/Users/manolo/Documents/Personales/Estudios/Máster Big Data y Data Science/Asignaturas/14MBID - TFM/Datasets/'
path = '/content/drive/My Drive/TFM/Datasets/'

# %% [markdown]
# ## Importación del dataframe

# %%
df_2mano = pd.read_excel(path+'df_2mano.xlsx', index_col=[0])

# %%
df_2mano.dtypes
# Out:
# Marca           object
# Modelo          object
# Precio           int64
# Combustible     object
# Año              int64
# Kilometraje      int64
# Potencia       float64
# Cambio          object
# Fotos            int64
# Provincia       object
# dtype: object

# %% [markdown]
# ## Estadística descriptiva

# %% [markdown]
# ### Variables numéricas

# %% [markdown]
# Realizamos un análisis descriptivo que nos permita ver si es necesario hacer algunas modificaciones adicionales en el dataframe a las ya realizadas durante el preprocesado y limpieza

# %%
df_2mano.describe()
# Out:
#              Precio           Año   Kilometraje      Potencia         Fotos
# count  7.918800e+04  79188.000000  7.918800e+04  79188.000000  79188.000000
# mean   2.516295e+04   2013.800563  1.035688e+05    156.512262     17.787480
# std    1.140646e+05      6.648264  1.113897e+05     96.053652     12.551707
# min    7.000000e+00   1970.000000  0.000000e+00      1.000000      0.000000
# 25%    7.500000e+03   2009.000000  2.430150e+04    110.000000      9.000000
# 50%    1.530000e+04   2016.000000  8.400000e+04    131.000000     15.000000
# 75%    2.490000e+04   2019.000000  1.570000e+05    170.000000     25.000000
# max    1.208790e+07   2022.000000  8.067058e+06   3239.000000    212.000000

# %% [markdown]
# Se observa que el precio medio de venta es de unos 25000 euros. El año promedio es de sobre 2014, existen coches en venta matriculados en 1970.

# %%
sns.set(style="white")
sns.boxplot(data=df_2mano[['Precio']])
plt.xticks(rotation=0)
# Out:
# (array([0]), <a list of 1 Text major ticklabel objects>)

# %% [markdown]
# Hay coches con un valor muy bajo (unos 100 euros) y otros excesivamente altos (el máximo está en más de 1e7).
#
# Vamos a ver los coches que tiene una valor inferior a 300 euros

# %%
df_2mano.loc[df_2mano['Precio'] <= 300]
# Out:
#                Marca    Modelo  Precio Combustible   Año  Kilometraje  \
# 3778         CITROEN    XANTIA     300    Gasolina  1997       190000
# 5119            SEAT     IBIZA     300    Gasolina  2002        70000
# 9174            FORD    MONDEO     300      Diesel  1996       246000
# 14049           OPEL    VECTRA     300    Gasolina  2003        90000
# 15962           FORD    ESCORT     300    Gasolina  1998       190000
# 17312        CITROEN      SAXO     300    Gasolina  1996       353335
# 21318           FORD    FIESTA     300      Diesel  1995        49000
# 22912           OPEL     ASTRA     300      Diesel  2002       240000
# 23334           SEAT   CORDOBA     300    Gasolina  1998       200000
# 26252     VOLKSWAGEN    BEETLE     300    Gasolina  2000       100000
# 26537           FIAT  SEICENTO     300    Gasolina  2005       111111
# 26795           OPEL     TIGRA     300    Gasolina  1998       275790
# 26908        CITROEN        AX     300      Diesel  1996       268000
# 29294         NISSAN    ALMERA     300      Diesel  1999        70000
# 31173           AUDI        A3     300    Gasolina  2003        85000
# 31576        RENAULT    MÉGANE     300      Diesel  1999       186000
# 32003        PEUGEOT       505     300    Gasolina  1980       150000
# 32093       CHRYSLER   VOYAGER     300      Diesel  2001       475300
# 36354         DAEWOO     KALOS     300    Gasolina  2003       130000
# 40400         NISSAN    ALMERA     300      Diesel  2001       140000
# 41632           SEAT     IBIZA     300    Gasolina  1999       178000
# 42462           OPEL     ASTRA     300    Gasolina  1998       150000
# 55240            BMW   SERIE 3     100      Diesel  2019        10000
# 55466  MERCEDES-BENZ   CLASE M      13      Diesel  2008       225000
# 55964        RENAULT      CLIO       7      Diesel  2014       115000
# 68066         ALPINA       XD3     111      Diesel  2021          111
# 68488         ALPINA       XD3     111      Diesel  2021         1111
# 68489         ALPINA       XD3     111      Diesel  2021         1111
#
#        Potencia      Cambio  Fotos           Provincia
# 3778       90.0      Manual      0           Tarragona
# 5119      100.0      Manual      9            Albacete
# 9174      145.0      Manual      0           Salamanca
# 14049     147.0      Manual      1           Barcelona
# 15962     105.0      Manual      0  Sta. Cruz Tenerife
# 17312      60.0      Manual      0  Sta. Cruz Tenerife
# 21318      82.0      Manual      0               Ávila
# 22912     110.0      Manual      0               Cádiz
# 23334      90.0      Manual      1  Sta. Cruz Tenerife
# 26252     115.0      Manual      0     Balears (Illes)
# 26537      54.0      Manual      5        Palmas (Las)
# 26795      80.0      Manual      0        Palmas (Las)
# 26908      50.0      Manual      0              Málaga
# 29294     110.0      Manual      0              Málaga
# 31173     140.0      Manual      4     Balears (Illes)
# 31576     110.0      Manual      5             Sevilla
# 32003     108.0      Manual      1              Girona
# 32093     115.0      Manual      3            Valencia
# 36354      72.0      Manual      2            Asturias
# 40400     110.0      Manual      3           Barcelona
# 41632      90.0      Manual      0        Palmas (Las)
# 42462     110.0      Manual      0          Rioja (La)
# 55240     190.0  Automatico     13            Palencia
# 55466     224.0  Automatico      0            Asturias
# 55964      75.0      Manual      0              Madrid
# 68066     300.0  Automatico      1              Toledo
# 68488     300.0  Automatico      0              Toledo
# 68489     300.0  Automatico      1              Toledo

# %% [markdown]
# Vamos a eliminar los coches que tienen un precio inferior a 300 euros, puesto que parece que son una errata

# %%
df_2mano = df_2mano.loc[(df_2mano['Precio'] >= 300)]

# %% [markdown]
# Vemos los coches que tienen un precio excesivamente alto

# %%
df_2mano.loc[df_2mano['Precio'] >= 200000]
# Out:
#                Marca       Modelo  Precio Combustible   Año  Kilometraje  \
# 197          PORSCHE          911  410000    Gasolina  2019          150
# 3761   MERCEDES-BENZ      CLASE G  358900    Gasolina  2019         4300
# 4528         PORSCHE          911  389000    Gasolina  2018        15000
# 5555   MERCEDES-BENZ      CLASE G  322900    Gasolina  2020          200
# 6023         FERRARI          812  305400    Gasolina  2019        24000
# ...              ...          ...     ...         ...   ...          ...
# 77407  MERCEDES-BENZ      CLASE G  229990    Gasolina  2019        40000
# 78009  MERCEDES-BENZ      CLASE G  224900    Gasolina  2018        35400
# 78376        FERRARI          488  234900    Gasolina  2016        18884
# 78499        FERRARI          488  254999    Gasolina  2017        14900
# 78824        BENTLEY  CONTINENTAL  218000    Gasolina  2019        31750
#
#        Potencia      Cambio  Fotos   Provincia
# 197       510.0      Manual     12      Girona
# 3761      585.0  Automatico     19   Barcelona
# 4528      700.0  Automatico     22      Madrid
# 5555      585.0  Automatico     18   Barcelona
# 6023      800.0  Automatico     13    Valencia
# ...         ...         ...    ...         ...
# 77407     585.0  Automatico     30  Pontevedra
# 78009     585.0  Automatico     39    Valencia
# 78376     670.0  Automatico     21      Málaga
# 78499     670.0  Automatico     26      Málaga
# 78824     635.0  Automatico      1   Barcelona
#
# [772 rows x 10 columns]

# %% [markdown]
# Vemos un histograma con la distribución de precios

# %%
sns.distplot(df_2mano['Precio'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Vemos que son coches de marcas premium y que apenas hay instancias con precios superiores a 200000 euros (sólo 772 instancias)
#
# No son muchos instancias, pero seguramente van a hacer que nuestro modelo no sea excesivamente bueno prediciendo en el rango alto de valores.
#
# Podríamos tomar la decisión de eliminar esas instancias, pero entonces nuestro modelo no recogería estas "anomalías". Tomamos la decisión de mantenerlas (al menos por el momento)

# %%
#skewness and kurtosis
print("Skewness: %f" % df_2mano['Precio'].skew())
print("Kurtosis: %f" % df_2mano['Precio'].kurt())
# Out:
# Skewness: 47.617662
# Kurtosis: 3367.261183

# %% [markdown]
# Los valores muestran que la distribución es bastante asimétrica (con asimetría positiva) y con gran concentración de valores respecto a la media

# %%
sns.set(style="white")
sns.boxplot(data=df_2mano[['Kilometraje']])
plt.xticks(rotation=0)
# Out:
# (array([0]), <a list of 1 Text major ticklabel objects>)

# %% [markdown]
# Hay coches que tienen un kilometraje excesivo. Vemos cuáles son

# %%
df_2mano.loc[df_2mano['Kilometraje'] >= 600000]
# Out:
#                Marca   Modelo  Precio Combustible   Año  Kilometraje  \
# 1337         CITROEN       C5    1200      Diesel  2007      2010000
# 1973   MERCEDES-BENZ      300    3500    Gasolina  1990      2450000
# 2811   MERCEDES-BENZ  CLASE E    7990      Diesel  2011       650000
# 3176            SEAT   TOLEDO    1700      Diesel  2002      3000000
# 4434            SEAT    IBIZA    1800    Gasolina  2009      1134000
# ...              ...      ...     ...         ...   ...          ...
# 59249     VOLKSWAGEN     GOLF    4500      Diesel  2009       605900
# 59250          SKODA   SUPERB    8900      Diesel  2016       600000
# 59251         TOYOTA    PRIUS    3750     Hibrido  2010       600000
# 77010           MINI     MINI   19990    Gasolina  2019      1692814
# 77271           MINI     MINI   19990    Gasolina  2019      1692814
#
#        Potencia      Cambio  Fotos    Provincia
# 1337      131.0      Manual      4       Toledo
# 1973      231.0  Automatico      0  Ciudad Real
# 2811      170.0  Automatico     16       Málaga
# 3176      110.0      Manual      8       Madrid
# 4434       90.0      Manual      2      Navarra
# ...         ...         ...    ...          ...
# 59249     110.0      Manual     12         Lugo
# 59250     150.0  Automatico     17       Málaga
# 59251     122.0  Automatico      0       Madrid
# 77010     102.0      Manual     24      Almería
# 77271     102.0      Manual     24       Málaga
#
# [86 rows x 10 columns]

# %% [markdown]
# Hay coches con más de un millón de kms. Podría ser cierto, pero parece complicado de creer (quizás sí si se tiene en cuenta la antigüedad de los mismos). Vamos a eliminar aquellos por encima del millón de kms.

# %%
df_2mano = df_2mano.loc[(df_2mano['Kilometraje'] <= 1e6)]

# %% [markdown]
# Vemos la distribución de Año de matriculación

# %%
sns.set(style="white")
sns.boxplot(data=df_2mano[['Año']])
plt.xticks(rotation=0)
# Out:
# (array([0]), <a list of 1 Text major ticklabel objects>)

# %% [markdown]
# Se observa que hay algunos registros con bastante antigüedad. Podríamos tomar la decisión de eliminar los que tienen una antigüedad muy importante (e.g., matriculaciones anteriores a 1990), pero en un principio dejamos todos

# %% [markdown]
# Vemos ahora la distribución de potencia y del número de fotos del anuncio

# %%
sns.set(style="white")
sns.boxplot(data=df_2mano[['Potencia', 'Fotos']])
plt.xticks(rotation=0)
# Out:
# (array([0, 1]), <a list of 2 Text major ticklabel objects>)

# %% [markdown]
# Hay algunos vehículos con potencias muy altas y otros con potencia demasiado bajas. Vamos a verlo

# %%
df_2mano.loc[df_2mano['Potencia'] <= 40]
# Out:
#             Marca    Modelo  Precio Combustible   Año  Kilometraje  Potencia  \
# 4858      RENAULT        R4     600    Gasolina  1996       100000      38.0
# 5658      INVICTA       D2S   21495   Electrico  2021            3      37.0
# 6625      RENAULT        R4    2700    Gasolina  1993          145      38.0
# 8665      RENAULT        R4    3000    Gasolina  1984       100000      38.0
# 10635     RENAULT        R4    4200    Gasolina  1990        64075      38.0
# 11430     RENAULT        R4    4500    Gasolina  1982        68000      40.0
# 18749     CITROEN       2CV    7000    Gasolina  1982        75000      29.0
# 21751     CITROEN       2CV    5000    Gasolina  1982        73500      29.0
# 24056     RENAULT        R4    1200    Gasolina  1987       100000      38.0
# 35868        SEAT  MARBELLA    3000    Gasolina  1989        13000      40.0
# 39679     RENAULT     TWIZY    4500    Gasolina  2012        39390      17.0
# 40365     RENAULT        R4    1500    Gasolina  1989       125000      38.0
# 40678     RENAULT        R4    1200    Gasolina  1990       100000      38.0
# 47376     INVICTA       D2S   21495   Electrico  2021            6      37.0
# 51818        SEAT  MARBELLA    1500    Gasolina  1994       136007      40.0
# 52112  LAND-ROVER  DEFENDER   16000      Diesel  1996       160000       1.0
# 52514         BMW        X3  363000    Gasolina  2007       363000      13.0
# 53436        FIAT      TIPO   11000      Diesel  1992       185000       1.0
# 53813         XEV      YOYO   10600   Electrico  2022           10      20.0
# 54977     PEUGEOT       RCZ    8000      Diesel  2010       180000       1.0
# 56095         XEV      YOYO   12900   Electrico  2022           10      20.0
# 56335     PEUGEOT       RCZ    3400      Diesel  2010       337000       4.0
# 56531       DODGE   CALIBER    3500    Gasolina  2007       168000       2.0
# 57066     HYUNDAI       H-1    6825      Diesel  2007        43341      16.0
# 58524     CITROEN        C1    8100    Gasolina  2018        60000       8.0
# 60000      NISSAN    ALMERA    1100      Diesel  1999       280000      13.0
# 60546         XEV      YOYO   13900   Electrico  2022            5      20.0
# 63650         XEV      YOYO   14400   Electrico  2022            5      20.0
# 64702     RENAULT     TWIZY    5900   Electrico  2014        27000      17.0
# 66172         XEV      YOYO   12900   Electrico  2022            0      20.0
# 66805         XEV      YOYO   13900   Electrico  2022            5      20.0
# 67336     RENAULT     TWIZY   11370   Electrico  2021           10      17.0
# 67337        AUDI        A6   50700      Diesel  2022           10       2.0
# 67503        AUDI        Q8   74200      Diesel  2022           10      16.0
# 67517        AUDI        Q7   64400      Diesel  2022           10      16.0
# 68091     RENAULT     TWIZY   10600   Electrico  2020          140      17.0
# 68119     CITROEN        C1    7700   Electrico  2021          173       8.0
# 68178     CITROEN       AMI    7890   Electrico  2021          353       8.0
# 68752         XEV      YOYO   11990   Electrico  2021         2249      20.0
# 68927         XEV      YOYO   14600   Electrico  2022         3000      20.0
# 69758     RENAULT     TWIZY    6324   Electrico  2013         5930      17.0
# 69917     RENAULT     TWIZY    9800   Electrico  2018         6317      17.0
# 71971     RENAULT     TWIZY    6000   Electrico  2013         9100      17.0
# 72157     RENAULT     TWIZY    6500   Electrico  2017         9700      17.0
#
#            Cambio  Fotos     Provincia
# 4858       Manual      5        Málaga
# 5658   Automatico     16        Burgos
# 6625       Manual      9          Jaén
# 8665       Manual      4        Murcia
# 10635      Manual      9        Murcia
# 11430      Manual     13        Málaga
# 18749      Manual     14        Madrid
# 21751      Manual      7    Valladolid
# 24056      Manual      0       Cáceres
# 35868      Manual      1       Córdoba
# 39679  Automatico      6         Cádiz
# 40365      Manual      4     Barcelona
# 40678      Manual      6       Cáceres
# 47376  Automatico     15        Burgos
# 51818      Manual      8   Ciudad Real
# 52112      Manual      6  Palmas (Las)
# 52514      Manual      2       Sevilla
# 53436      Manual     10        Murcia
# 53813  Automatico     15      Alicante
# 54977      Manual      0  Palmas (Las)
# 56095  Automatico      5     Barcelona
# 56335      Manual      3        Toledo
# 56531  Automatico      4    Valladolid
# 57066      Manual      4  Palmas (Las)
# 58524      Manual      0        Huelva
# 60000      Manual      5   Ciudad Real
# 60546  Automatico      8     Barcelona
# 63650  Automatico      9     Barcelona
# 64702  Automatico     19      Alicante
# 66172  Automatico     22     Barcelona
# 66805  Automatico     24     Barcelona
# 67336  Automatico     17     Tarragona
# 67337  Automatico      9   Ciudad Real
# 67503  Automatico      5   Ciudad Real
# 67517  Automatico      4   Ciudad Real
# 68091  Automatico     32    Pontevedra
# 68119  Automatico     15        Zamora
# 68178  Automatico     26     Barcelona
# 68752  Automatico     39        Madrid
# 68927  Automatico      3        Girona
# 69758  Automatico     14        Girona
# 69917  Automatico      8       Córdoba
# 71971  Automatico     10       Cáceres
# 72157  Automatico     15        Málaga

# %%
df_2mano.loc[df_2mano['Potencia'] >= 900]
# Out:
#                Marca   Modelo    Precio Combustible   Año  Kilometraje  \
# 50146         JAGUAR      XJS      3900    Gasolina  1996       122001
# 50156        FERRARI     SF90    615000     Hibrido  2020           50
# 52283  MERCEDES-BENZ  CLASE V     29900      Diesel  1998        90312
# 54678        BUGATTI   CHIRON  12087900    Gasolina  2021           50
# 54679        BUGATTI   CHIRON   4950000    Gasolina  2021           80
# 54682        BUGATTI   CHIRON   4850000    Gasolina  2021         5100
# 54684        BUGATTI   VEYRON   3650000    Gasolina  2015         4500
# 54690        FERRARI     SF90    679000     Hibrido  2021          500
# 54691        FERRARI     SF90    649000     Hibrido  2021         7400
# 54692        FERRARI     SF90    645000     Hibrido  2021         7500
# 54693        FERRARI     SF90    640000     Hibrido  2021          490
# 54694        FERRARI     SF90    629000     Hibrido  2021         3900
# 54697        FERRARI     SF90    529000     Hibrido  2021         2900
# 54711        FERRARI     SF90    635000     Hibrido  2021          250
# 54713        BUGATTI   CHIRON   4400800    Gasolina  2018           90
# 54714        BUGATTI   CHIRON   4525000    Gasolina  2019           80
# 54715        BUGATTI   CHIRON   3485000    Gasolina  2017         1590
# 54719        BUGATTI   VEYRON   1772900    Gasolina  2009         1700
# 54725     KOENIGSEGG   REGERA   3750000     Hibrido  2022           80
# 54726        BUGATTI   CHIRON   4140000    Gasolina  2020         9600
# 54781        BUGATTI   VEYRON   3400000    Gasolina  2013         2800
# 56666        FERRARI     SF90    686900     Hibrido  2021         2594
# 56690        FERRARI     SF90    629900     Hibrido  2021         7200
# 56693        BUGATTI   VEYRON   3355900    Gasolina  2013          680
# 57695        FERRARI     SF90    548900     Hibrido  2020         8600
# 57941        FERRARI     SF90    623900     Hibrido  2021          220
# 58317        BUGATTI   CHIRON   3834900    Gasolina  2018          765
# 60163          VOLVO     XC70      6100      Diesel  2006       270000
# 62412  MERCEDES-BENZ  CLASE A     30500    Gasolina  2019        56000
# 64626        FERRARI     SF90    489000     Hibrido  2022           10
# 66551        BUGATTI   CHIRON   5419900    Gasolina  2022            1
# 67759        FERRARI     SF90    625000     Hibrido  2022           20
# 67910        FERRARI     SF90   1146900     Hibrido  2022           50
# 68088        FERRARI     SF90   1056900     Hibrido  2022          130
# 68190        FERRARI     SF90    649999     Hibrido  2021          400
# 68192        BUGATTI   CHIRON   3679900    Gasolina  2018          400
# 68200        FERRARI     SF90    539500     Hibrido  2021          450
# 68381        FERRARI     SF90    689900     Hibrido  2021          900
# 68382        FERRARI     SF90    712900     Hibrido  2021          900
# 68408        FERRARI     SF90    649999     Hibrido  2021         1000
# 68461        FERRARI     SF90    594900     Hibrido  2021         1000
# 68525        FERRARI     SF90    539900     Hibrido  2020         1248
# 68555        FERRARI     SF90    637900     Hibrido  2021         1450
# 68578        BUGATTI     DIVO  10300000    Gasolina  2021         1500
# 68583        FERRARI     SF90    890000     Hibrido  2021         1500
# 68605          DODGE    VIPER    258900    Gasolina  2005         1688
# 68873        FERRARI     SF90    753900     Hibrido  2021         2988
# 68966        FERRARI     SF90    739900     Hibrido  2021         3200
# 69037        FERRARI     SF90    570900     Hibrido  2021         3500
#
#        Potencia      Cambio  Fotos     Provincia
# 50146    3239.0      Manual      4       Sevilla
# 50156    1000.0  Automatico      1        Murcia
# 52283    2874.0      Manual      7  Palmas (Las)
# 54678    1500.0  Automatico      1        Murcia
# 54679    1500.0  Automatico      1        Murcia
# 54682    1500.0  Automatico      1        Murcia
# 54684    1500.0  Automatico      2        Murcia
# 54690    1000.0  Automatico     20        Murcia
# 54691    1000.0  Automatico      8        Murcia
# 54692    1000.0  Automatico      8        Murcia
# 54693    1000.0  Automatico     16        Murcia
# 54694    1000.0  Automatico      9        Murcia
# 54697    1000.0  Automatico      1        Murcia
# 54711    1000.0  Automatico     15        Murcia
# 54713    1500.0  Automatico      6        Murcia
# 54714    1500.0  Automatico      8        Murcia
# 54715    1500.0  Automatico      5        Murcia
# 54719    1500.0  Automatico     28        Madrid
# 54725    1509.0  Automatico      1        Murcia
# 54726    1500.0  Automatico      1        Murcia
# 54781    1500.0  Automatico      1        Murcia
# 56666    1000.0  Automatico     15        Madrid
# 56690    1000.0  Automatico     26        Madrid
# 56693    1500.0  Automatico     15        Madrid
# 57695    1000.0  Automatico     29        Madrid
# 57941    1000.0  Automatico     13        Madrid
# 58317    1500.0  Automatico     30        Madrid
# 60163    2200.0      Manual     11       Córdoba
# 62412    1332.0      Manual      0      Valencia
# 64626    1000.0  Automatico      8        Murcia
# 66551    1500.0  Automatico      1        Madrid
# 67759    1000.0  Automatico      1        Murcia
# 67910    1000.0  Automatico     21        Madrid
# 68088    1000.0  Automatico     15        Madrid
# 68190    1000.0  Automatico     24        Málaga
# 68192    1500.0  Automatico     11        Madrid
# 68200    1000.0  Automatico      8        Murcia
# 68381    1000.0  Automatico     25        Madrid
# 68382    1000.0  Automatico     20        Madrid
# 68408    1000.0  Automatico     63      Valencia
# 68461    1000.0  Automatico     30        Madrid
# 68525    1000.0  Automatico     13        Málaga
# 68555    1000.0  Automatico     29        Madrid
# 68578    1500.0  Automatico      4        Madrid
# 68583    1000.0  Automatico      1        Murcia
# 68605    1100.0      Manual      8        Málaga
# 68873    1000.0  Automatico     13        Madrid
# 68966    1000.0  Automatico      8        Murcia
# 69037    1000.0  Automatico     16        Madrid

# %% [markdown]
# Se observa que hay errores en los valores de potencia inferiores a 20 CV. También consideramos que los valores superiores a más de 1500 CV son un error. Igualmente, la instancia 62412 es un error (se elimina)

# %%
df_2mano = df_2mano.loc[(df_2mano['Potencia'] >= 20)]
df_2mano = df_2mano.loc[(df_2mano['Potencia'] <= 1500)]
df_2mano.drop(df_2mano.iloc[62348].name, inplace = True)

# %% [markdown]
# Respecto de las fotografías, es razonable que haya una gran variabilidad, aunque aquellos casos en los que se disponen de más de 100 fotos parecen excesivos. En cualquier caso, esta característica está por ver si aporta algo o no.

# %%
df_2mano.reset_index(inplace = True, drop = True)

# %%
df_2mano.describe()
# Out:
#              Precio           Año    Kilometraje      Potencia         Fotos
# count  7.910700e+04  79107.000000   79107.000000  79107.000000  79107.000000
# mean   2.512632e+04   2013.804252  102210.487340    156.439544     17.796832
# std    1.133438e+05      6.645357   91177.345593     94.541680     12.551117
# min    3.000000e+02   1970.000000       0.000000     20.000000      0.000000
# 25%    7.500000e+03   2009.000000   24294.500000    110.000000      9.000000
# 50%    1.530000e+04   2016.000000   84000.000000    131.000000     15.000000
# 75%    2.490000e+04   2019.000000  156900.000000    170.000000     25.000000
# max    1.208790e+07   2022.000000  999999.000000   1500.000000    212.000000

# %% [markdown]
# Podemos ver también la correlación que hay entre las variables numéricas (excluyendo la variable objetivo, que es la que precisamente queremos correlacionar).
#
# Para esto, nos quedamos sólo con las variables numéricas y quitamos la columna 'Precio'

# %%
df_2mano_num = df_2mano.select_dtypes(include=[np.number])
df_2mano_num = transpose(df_2mano_num.drop(['Precio'], axis = 1))
nombres_num = df_2mano_num.index

# %%
R = corrcoef(df_2mano_num)
sns.set(style="white")
mask = np.zeros_like(R, dtype = bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(10, 8))

cmap = sns.diverging_palette(200, 10, as_cmap=True)

sns.heatmap(R, mask=mask, cmap=cmap, vmax=1,
            square=True, xticklabels=nombres_num, yticklabels=nombres_num, annot=True, fmt=".2f",
            linewidths=.5, cbar_kws={"shrink": .8}, ax=ax)

# %% [markdown]
# Se observa que hay una correlación moderada entre los kilometros y el año (algo que tiene sentido, ya que mientras más nuevo sea el coche, menos kilómetros suele haber recorrido). Decidimos no quitar ninguna de las variables

# %% [markdown]
# Si se analiza la correlación incluyendo el precio de venta (variable objetivo)

# %%
df_2mano_num = df_2mano.select_dtypes(include=[np.number])
df_2mano_num = transpose(df_2mano_num)
nombres_num = df_2mano_num.index

# %%
R = corrcoef(df_2mano_num)
sns.set(style="white")
mask = np.zeros_like(R, dtype = bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(10, 8))

cmap = sns.diverging_palette(200, 10, as_cmap=True)

sns.heatmap(R, mask=mask, cmap=cmap, vmax=1,
            square=True, xticklabels=nombres_num, yticklabels=nombres_num, annot=True, fmt=".2f",
            linewidths=.5, cbar_kws={"shrink": .8}, ax=ax)

# %% [markdown]
# ### Variables categóricas

# %% [markdown]
# En el dataframe existen variables que son de tipo categórico, como son la marca, el modelo, o la provincia.
#
# Verificamos en primer lugar el número de categorías que tenemos en cada una de las variables de este tipo

# %%
df_2mano_cat = df_2mano.select_dtypes(exclude=[np.number])
cat_cols = df_2mano_cat.columns.values
df_2mano_cat.nunique(axis=0)
# Out:
# Marca           90
# Modelo         972
# Combustible      6
# Cambio           2
# Provincia       52
# dtype: int64

# %% [markdown]
# Vemos que hay muchas categorías en algunas de las variables, como es el caso de Modelo (972 categorías)

# %% [markdown]
# Vamos a ver la distribución de categorías en la variable Marca, ya que tiene un número más o menos manejable

# %%
sns.set(style="white")
fig, ax = plt.subplots(figsize=(40, 16))
df_2mano['Marca'].value_counts().plot.bar()

# %%
sns.set(style="white")
df_2mano['Provincia'].value_counts().plot.bar()

# %%
sns.set(style="white")
fig, ax = plt.subplots(figsize=(140, 18))
df_2mano['Modelo'].value_counts().plot.bar()

# %% [markdown]
# Podemos ver agrupado por marcas y modelos

# %%
fig = px.treemap(data_frame= df_2mano, path=["Marca","Modelo","Combustible"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8860eb54-b21a-497a-afe1-ae0caf3cba34" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8860eb54-b21a-497a-afe1-ae0caf3cba34")) {                    Plotly.newPlot(                        "8860eb54-b21a-497a-afe1-ae0caf3cba34",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["UMM/100/Diesel","NISSAN/100 NX/Diesel","PEUGEOT/1007/Diesel","MERCEDES-BENZ/100D/Diesel","PEUGEOT/106/Diesel","PEUGEOT/107/Diesel","MERCEDES-BENZ/140D/Diesel","ALFA ROMEO/146/Diesel","ALFA ROMEO/147/Diesel","ALFA ROMEO/156/Diesel","ALFA ROMEO/159/Diesel","MERCEDES-BENZ/180D/Diesel","RENAULT/19/Diesel","MERCEDES-BENZ/190/Diesel","MERCEDES-BENZ/200/Diesel","ROVER/200/Diesel","PEUGEOT/2008/Diesel","PEUGEOT/205/Diesel","PEUGEOT/206/Diesel","PEUGEOT/207/Diesel","PEUGEOT/208/Diesel","MERCEDES-BENZ/220/Diesel","ROVER/25/Diesel","MERCEDES-BENZ/280/Diesel","MERCEDES-BENZ/300/Diesel","SANTANA/300/Diesel","PEUGEOT/3008/Diesel","CHRYSLER/300C/Diesel","PEUGEOT/306/Diesel","PEUGEOT/307/Diesel","PEUGEOT/308/Diesel","PEUGEOT/309/Diesel","SANTANA/350/Diesel","TOYOTA/4-RUNNER/Diesel","MERCEDES-BENZ/400/Diesel","PEUGEOT/4007/Diesel","PEUGEOT/4008/Diesel","PEUGEOT/405/Diesel","PEUGEOT/406/Diesel","PEUGEOT/407/Diesel","ROVER/45/Diesel","FIAT/500/Diesel","PEUGEOT/5008/Diesel","FIAT/500L/Diesel","FIAT/500X/Diesel","PEUGEOT/508/Diesel","ROVER/600/Diesel","PEUGEOT/607/Diesel","MAZDA/626/Diesel","ROVER/75/Diesel","AUDI/80/Diesel","PEUGEOT/806/Diesel","PEUGEOT/807/Diesel","SAAB/9-3/Diesel","SAAB/9-5/Diesel","AUDI/A1/Diesel","AUDI/A2/Diesel","AUDI/A3/Diesel","AUDI/A4/Diesel","AUDI/A5/Diesel","AUDI/A6/Diesel","AUDI/A7/Diesel","AUDI/A8/Diesel","HYUNDAI/ACCENT/Diesel","HONDA/ACCORD/Diesel","SUZUKI/ACROSS/Diesel","SSANGYONG/ACTYON/Diesel","SEAT/ALHAMBRA/Diesel","AUDI/ALLROAD/Diesel","NISSAN/ALMERA/Diesel","NISSAN/ALMERA TINO/Diesel","SEAT/ALTEA/Diesel","SEAT/ALTEA XL/Diesel","VOLKSWAGEN/AMAROK/Diesel","SANTANA/ANIBAL/Diesel","OPEL/ANTARA/Diesel","TATA/ARIA/Diesel","RENAULT/ARKANA/Diesel","SEAT/ARONA/Diesel","SEAT/AROSA/Diesel","VOLKSWAGEN/ARTEON/Diesel","OPEL/ASTRA/Diesel","MITSUBISHI/ASX/Diesel","SEAT/ATECA/Diesel","TOYOTA/AURIS/Diesel","DODGE/AVENGER/Diesel","TOYOTA/AVENSIS/Diesel","CHEVROLET/AVEO/Diesel","CITROEN/AX/Diesel","TOYOTA/AYGO/Diesel","FORD/B-MAX/Diesel","VOLKSWAGEN/BEETLE/Diesel","BENTLEY/BENTAYGA/Diesel","CITROEN/BERLINGO/Diesel","PEUGEOT/BIPPER/Diesel","CADILLAC/BLS/Diesel","VOLKSWAGEN/BORA/Diesel","PEUGEOT/BOXER/Diesel","FIAT/BRAVA/Diesel","FIAT/BRAVO/Diesel","ALFA ROMEO/BRERA/Diesel","CITROEN/BX/Diesel","CITROEN/C-15/Diesel","CITROEN/C-CROSSER/Diesel","CITROEN/C-ELYS\u00c9E/Diesel","FORD/C-MAX/Diesel","CITROEN/C1/Diesel","CITROEN/C2/Diesel","CITROEN/C3/Diesel","CITROEN/C3 AIRCROSS/Diesel","CITROEN/C3 PICASSO/Diesel","CITROEN/C3 PLURIEL/Diesel","VOLVO/C30/Diesel","CITROEN/C4/Diesel","CITROEN/C4 AIRCROSS/Diesel","CITROEN/C4 CACTUS/Diesel","CITROEN/C4 PICASSO/Diesel","CITROEN/C4 SED\u00c1N/Diesel","CITROEN/C4 SPACETOURER/Diesel","CITROEN/C5/Diesel","CITROEN/C5 AIRCROSS/Diesel","CITROEN/C6/Diesel","VOLVO/C70/Diesel","CITROEN/C8/Diesel","OPEL/CABRIO/Diesel","AUDI/CABRIOLET/Diesel","NISSAN/CABSTAR/Diesel","VOLKSWAGEN/CADDY/Diesel","DODGE/CALIBER/Diesel","VOLKSWAGEN/CALIFORNIA/Diesel","NISSAN/CAMION/Diesel","MITSUBISHI/CANTER/Diesel","CHEVROLET/CAPTIVA/Diesel","RENAULT/CAPTUR/Diesel","VOLKSWAGEN/CARAVELLE/Diesel","KIA/CARENS/Diesel","MITSUBISHI/CARISMA/Diesel","KIA/CARNIVAL/Diesel","PORSCHE/CAYENNE/Diesel","VOLKSWAGEN/CC/Diesel","KIA/CEED/Diesel","KIA/CERATO/Diesel","JEEP/CHEROKEE/Diesel","MERCEDES-BENZ/CITAN/Diesel","SMART/CITY-COUP\u00c9/Dies ...

# %%
sns.set(style="white")
sns.countplot(y="Combustible", data=(df_2mano))

# %%
sns.set(style="white")
sns.countplot(y="Cambio", data=(df_2mano))

# %% [markdown]
# Vemos como queda el dataframe usando variables dummies (variables ficticias) para codificar las variables categóricas.

# %%
df_2mano_dummies = pd.get_dummies(df_2mano, sparse = True)

# %%
df_2mano_dummies.shape
# Out:
# (79107, 1127)

# %% [markdown]
# Al usar variables dummies, el número de características se vuelve muy grande. De ese modo, vamos a proceder a realizar el modelado en un principio con todas las características y, posteriormente, haciendo una reducción de características usando el FeatureSelectorpara ver si es posible hacer un ajuste razonable con menos variables

# %% [markdown]
# ## Modelado para predicción del precio de vehículos usados

# %% [markdown]
# Hacemos el ajuste usando todas las variables del dataframe

# %% [markdown]
# ### Preprocesado

# %% [markdown]
# Al tener variables numéricas y categóricas, hacemos un preprocesado en primer lugar

# %%
num_feat = ['Año', 'Kilometraje', 'Potencia', 'Fotos']
cat_feat = ['Marca', 'Modelo', 'Combustible', 'Cambio', 'Provincia']

feat = num_feat + cat_feat

target = 'Precio'

# %% [markdown]
# Separamos dos conjuntos de datos, utilizando un 25% de los datos para test y el resto para entrenar

# %%
X_train, X_test, y_train, y_test = train_test_split(
                                        df_2mano.drop(columns = target),
                                        df_2mano[target],
                                        test_size=0.25,
                                        random_state = 123
                                    )

print("Dimensiones del dataframe original",df_2mano.shape)
print("Dimensiones del dataframe sin variable objetivo para train", X_train.shape)
print("variable objetivo para train", y_train.shape)
print("Dimensiones del dataframe sin variable objetivo para test", X_test.shape)
print("variable objetivo para test", y_test.shape)
# Out:
# Dimensiones del dataframe original (79107, 10)
# Dimensiones del dataframe sin variable objetivo para train (59330, 9)
# variable objetivo para train (59330,)
# Dimensiones del dataframe sin variable objetivo para test (19777, 9)
# variable objetivo para test (19777,)

# %% [markdown]
# Se hace un reset de índices

# %%
X_train.reset_index(drop = True, inplace = True)
X_test.reset_index(drop = True, inplace = True)
y_train.reset_index(drop = True, inplace = True)
y_test.reset_index(drop = True, inplace = True)

# %% [markdown]
# Creamos un transformer para estandarizar las variables numéricas y para hacer un one hot encoding en las categoricas

# %%
data_transformer = ColumnTransformer(
  transformers = [
    ('rescale numeric', preprocessing.StandardScaler(), num_feat),
    ('recode categorical', 
      preprocessing.OneHotEncoder(handle_unknown = 'ignore', sparse = False), 
      cat_feat)
    ])

# %% [markdown]
# ### Creación del pipeline con los modelos

# %% [markdown]
# Creamos el pipeline que aplica la transformación y asigna el modelo a usar.
# Realmente, para los modelos tipo árbol (dtr, rfr y gbr) no sería necesario estandarizar (pero tampoco pasa nada si se hace)

# %%
dtr = Pipeline(steps = [("prep", data_transformer), ('dtr', DecisionTreeRegressor())])
rfr = Pipeline(steps = [("prep", data_transformer), ('rfr', RandomForestRegressor())])
gbr = Pipeline(steps = [("prep", data_transformer), ('gbr', GradientBoostingRegressor())])
lr = Pipeline(steps=[("prep", data_transformer), ("lr",LinearRegression())])
ridge = Pipeline(steps=[("prep", data_transformer), ("ridge",Ridge())])
lasso = Pipeline(steps=[("prep", data_transformer), ("lasso",Lasso())])
knr = Pipeline(steps=[("prep", data_transformer), ("knr",KNeighborsRegressor())])
#svr = Pipeline(steps=[("prep", data_transformer), ("svr",SVR())]) No acaba nunca de coverger
lsvr= Pipeline(steps=[("prep", data_transformer), ("lsvr",LinearSVR())])
mlp = Pipeline(steps=[("prep", data_transformer), ("mlp",MLPRegressor())])
xgr = Pipeline(steps=[("prep", data_transformer), ("xgr",XGBRegressor())])

# %% [markdown]
# ### Búsqueda inicial de hiperparámetros: RandomSearch

# %% [markdown]
# Se utiliza inicialmente la técnica de RandomSearchCV, para buscar unos parámetros iniciales que luego se puedan afinar con GridSearchCV

# %%
# Arbol de decisión
grid_rs_dtr = {"dtr__max_depth": list(np.arange(2, 20, step = 2)) 
              }
# Random Forest
grid_rs_rfr = {"rfr__n_estimators": list(np.arange(10, 100, step = 10)), 
                     
                     "rfr__max_depth": list(np.arange(10, 50, step = 10)), 
                      
                     "rfr__max_features": ["sqrt", 3, 4] 
                     }
# Gradient Boosting
grid_rs_gbr = {"gbr__loss": ["squared_error"],
                          "gbr__learning_rate": list(np.arange(0.05, 1, step = 0.1)), 
                          
                          "gbr__n_estimators": list(np.arange(5, 30, step = 5)), 
                          
                          "gbr__max_depth": list(np.arange(15, 30, step = 5)), 
                          
                          "gbr__subsample": list(np.arange(0.5, 1, step = 0.1)), 
                          
                          "gbr__max_features": ["sqrt", 4, 8], 
                          }
# Ridge
grid_rs_ridge= {'ridge__alpha': list(np.arange(0.1, 5, step = 0.2))}

# Lasso
grid_rs_lasso= {'lasso__alpha': list(np.arange(0.1, 5, step = 0.2))}

# KNeighbors
grid_rs_knr = {"knr__n_neighbors": list(np.arange(1, 15, step = 2)), 
                  "knr__weights": ["uniform","distance"]  
                  }

# Linear Suppport Vector Machine 
grid_rs_lsvr={"lsvr__tol":[0.001,0.0001], "lsvr__C": [0.1, 5.0, 50.0]}

# Multi layer perceptron
grid_rs_mlp = {"mlp__hidden_layer_sizes": [(4,),             
                                        (4,4),           
                                        (30,),          
                                        (30,30)],
            
           "mlp__activation": ["relu"], 
            
           "mlp__solver": ["adam"], 
            
           "mlp__alpha": [0.0, 0.1], 
            
           "mlp__validation_fraction": [0.1], 
           "mlp__early_stopping": [True],    
           "mlp__max_iter": [3000],
            
           "mlp__learning_rate_init": list(np.arange(0.001, 0.1, step = 0.01)) 
           }

# XGBRegressor

grid_rs_xgr = {'xgr__max_depth': list(np.arange(1, 10, step = 1)),
            'xgr__learning_rate': [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3],
            'xgr__n_estimators': list(np.arange(50, 200, step = 20))
            }

# %%
rs_dtr = RandomizedSearchCV(dtr, 
                    grid_rs_dtr,
                    n_iter = 20, 
                    cv=5, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)
rs_rfr = RandomizedSearchCV(rfr, 
                    grid_rs_rfr,
                    n_iter = 20, 
                    cv=5, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)

rs_gbr = RandomizedSearchCV(gbr, 
                    grid_rs_gbr,
                    n_iter = 20, 
                    cv=5, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)

rs_ridge = RandomizedSearchCV(ridge, 
                    grid_rs_ridge,
                    n_iter = 20, 
                    cv=5, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)

rs_lasso = RandomizedSearchCV(lasso, 
                    grid_rs_lasso,
                    n_iter = 20, 
                    cv=3, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)

rs_knr = RandomizedSearchCV(knr, 
                    grid_rs_knr,
                    n_iter = 20, 
                    cv=5, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)

rs_mlp = RandomizedSearchCV(mlp,
                      grid_rs_mlp,
                      n_iter = 20,
                      cv=5,
                      scoring='neg_mean_absolute_error',
                      verbose=1,
                      n_jobs=-1)

rs_lsvr = RandomizedSearchCV(lsvr,
                    grid_rs_lsvr,
                    n_iter = 20,
                    cv=5, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)

rs_xgr = RandomizedSearchCV(xgr, 
                    grid_rs_xgr,
                    n_iter = 20, 
                    cv=5, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)
rs_lr = GridSearchCV(lr,
                    param_grid={},
                    cv=10, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)

# %% [markdown]
# Se incluye tambien la regresión lineal, teniendo en cuenta que no tiene hiperparámetros

# %%
all_rs_searchs = {"rs_dtr":rs_dtr,
                    "rs_rfr":rs_rfr,
                    "rs_gbr":rs_gbr,
                    "rs_ridge":rs_ridge,
                    "rs_lasso":rs_lasso,
                    "rs_knr":rs_knr,
                    "rs_lsvr": rs_lsvr,
                    "rs_mlp":rs_mlp,
                    "rs_xgr": rs_xgr,
                    "rs_lr": rs_lr
                    }

# %% [markdown]
# #### Entrenamiento de los modelos

# %%
for nombre, grid_search in all_rs_searchs.items():
    start = time.time()
    print("Haciendo Random Search de %s..." % nombre)
    grid_search.fit(X_train, y_train)
    stop = time.time()
    print(f"Tiempo de entrenamiento: {stop - start} s")
# Out:
# Haciendo Random Search de rs_dtr...
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_search.py:292: UserWarning:
#
# The total space of parameters 9 is smaller than n_iter=20. Running 9 iterations. For exhaustive searches, use GridSearchCV.
# Tiempo de entrenamiento: 37.66904616355896 s
# Haciendo Random Search de rs_rfr...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Tiempo de entrenamiento: 111.94343042373657 s
# Haciendo Random Search de rs_gbr...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Tiempo de entrenamiento: 54.5964412689209 s
# Haciendo Random Search de rs_ridge...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Tiempo de entrenamiento: 35.90195870399475 s
# Haciendo Random Search de rs_lasso...
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.749e+13, tolerance: 5.402e+10
#
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_search.py:292: UserWarning:
#
# The total space of parameters 14 is smaller than n_iter=20. Running 14 iterations. For exhaustive searches, use GridSearchCV.
# Tiempo de entrenamiento: 212.79721784591675 s
# Haciendo Random Search de rs_knr...
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# Tiempo de entrenamiento: 338.5020282268524 s
# Haciendo Random Search de rs_lsvr...
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_search.py:292: UserWarning:
#
# The total space of parameters 6 is smaller than n_iter=20. Running 6 iterations. For exhaustive searches, use GridSearchCV.
# Tiempo de entrenamiento: 5.320127964019775 s
# Haciendo Random Search de rs_mlp...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Tiempo de entrenamiento: 2611.3436510562897 s
# Haciendo Random Search de rs_xgr...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /usr/local/lib/python3.8/dist-packages/joblib/externals/loky/process_executor.py:700: UserWarning:
#
# A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
# [17:03:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Tiempo de entrenamiento: 2787.234843492508 s
# Haciendo Random Search de rs_lr...
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Tiempo de entrenamiento: 20.746634244918823 s

# %% [markdown]
# Se evaluan el desempeño de los modelos tras usar RandomSearch, obteniendo la mejor puntuación de cada modelo. Para eso, hacemos pares modelo-puntuación y lo ordenamos (haciendo uso de un dataframe)

# %% [markdown]
# #### Desempeño de los modelos

# %%
best_score_rs = [(nombre_modelo, grid_search.best_score_)
                                  for nombre_modelo, grid_search           
                                  in all_rs_searchs.items()]

best_score_rs_df = pd.DataFrame(best_score_rs, 
                                columns=["RandomSearchCV", "Best score"]).sort_values(by="Best score", ascending=False)

best_score_rs_df
# Out:
#   RandomSearchCV    Best score
# 8         rs_xgr -4.615933e+03
# 7         rs_mlp -5.268540e+03
# 5         rs_knr -5.304437e+03
# 0         rs_dtr -5.368707e+03
# 1         rs_rfr -6.295628e+03
# 2         rs_gbr -7.034809e+03
# 4       rs_lasso -7.779151e+03
# 3       rs_ridge -7.918062e+03
# 6        rs_lsvr -9.265810e+03
# 9          rs_lr -2.425396e+11

# %% [markdown]
# Seleccionamos los 5 mejores modelos, a los que le haremos un GridSearch para afinar más los hiperparámetros. Para eso, vemos los valores de los mejores hiperparámetros obtenidos y vamos creando las mallas (grid) donde afinar los valores

# %% [markdown]
# ##### XGR

# %% [markdown]
# Vemos las métricas de error y lo bueno que es el ajuste con los hiperparámetros resultantes del RandomSearch

# %%
best_randomsearch = all_rs_searchs["rs_xgr"]
# Save the model best model
best_pipeline = best_randomsearch.best_estimator_
best_pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('prep',
#    ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                     ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#                                    ('recode categorical',
#                                     OneHotEncoder(handle_unknown='ignore',
#                                                   sparse=False),
#                                     ['Marca', 'Modelo', 'Combustible', 'Cambio',
#                                      'Provincia'])])),
#   ('xgr', XGBRegressor(learning_rate=0.3, max_depth=8, n_estimators=150))],
#  'verbose': False,
#  'prep': ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                   ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#                                  ('recode categorical',
#                                   OneHotEncoder(handle_unknown='ignore',
#                                                 sparse=False),
#                                   ['Marca', 'Modelo', 'Combustible', 'Cambio',
#                                    'Provincia'])]),
#  'xgr': XGBRegressor(learning_rate=0.3, max_depth=8, n_estimators=150),
#  'prep__n_jobs': None,
#  'prep__remainder': 'drop',
#  'prep__sparse_threshold': 0.3,
#  'prep__transformer_weights': None,
#  'prep__transformers': [('rescale numeric',
#    StandardScaler(),
#    ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#   ('recode categorical',
#    OneHotEncoder(handle_unknown='ignore', sparse=False),
#    ['Marca', 'Modelo', 'Combustible', 'Cambio', 'Provincia'])],
#  'prep__verbose': False,
#  'prep__verbose_feature_names_out': True,
#  'prep__rescale numeric': StandardScaler(),
#  'prep__recode categorical': OneHotEncoder(handle_unknown='ignore', sparse=False),
#  'prep__rescale numeric__copy': True,
#  'prep__rescale numeric__with_mean': True,
#  'prep__rescale numeric__with_std': True,
#  'prep__recode categorical__categories': 'auto',
#  'prep__recode categorical__drop': None,
#  'prep__recode categorical__dtype': numpy.float64,
#  'prep__recode categorical__handle_unknown': 'ignore',
#  'prep__recode categorical__sparse': False,
#  'xgr__base_score': 0.5,
#  'xgr__booster': 'gbtree',
#  'xgr__colsample_bylevel': 1,
#  'xgr__colsample_bynode': 1,
#  'xgr__colsample_bytree': 1,
#  'xgr__gamma': 0,
#  'xgr__importance_type': 'gain',
#  'xgr__learning_rate': 0.3,
#  'xgr__max_delta_step': 0,
#  'xgr__max_depth': 8,
#  'xgr__min_child_weight': 1,
#  'xgr__missing': None,
#  'xgr__n_estimators': 150,
#  'xgr__n_jobs': 1,
#  'xgr__nthread': None,
#  'xgr__objective': 'reg:linear',
#  'xgr__random_state': 0,
#  'xgr__reg_alpha': 0,
#  'xgr__reg_lambda': 1,
#  'xgr__scale_pos_weight': 1,
#  'xgr__seed': None,
#  'xgr__silent': None,
#  'xgr__subsample': 1,
#  'xgr__verbosity': 1}

# %%
mse = mean_squared_error(y_true=y_test, y_pred=best_pipeline.predict(X_test))
mae = mean_absolute_error(y_true=y_test,y_pred=best_pipeline.predict(X_test))
rmse = np.sqrt(mse)

print("MSE: " + str(mse))
print("MAE: " +  str(mae))
print("RMSE: " +  str(rmse))
# Out:
# MSE: 9318857391.112003
# MAE: 5731.14469325842
# RMSE: 96534.22911647455

# %%
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, rs_xgr)

# %% [markdown]
# A partir de los mejores valores del RandomSearch, fijamos la malla para el GridSearch que se usará afinando parámetros

# %%
grid_xgr = {'xgr__max_depth': [10, 11, 12],
            'xgr__learning_rate': [0.1, 0.15],
            'xgr__n_estimators': [150, 170, 190]
            }

# %% [markdown]
# ##### MLP

# %% [markdown]
# También se procede igual

# %%
best_randomsearch = all_rs_searchs["rs_mlp"]
# Save the model best model
best_pipeline = best_randomsearch.best_estimator_
best_pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('prep',
#    ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                     ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#                                    ('recode categorical',
#                                     OneHotEncoder(handle_unknown='ignore',
#                                                   sparse=False),
#                                     ['Marca', 'Modelo', 'Combustible', 'Cambio',
#                                      'Provincia'])])),
#   ('mlp',
#    MLPRegressor(alpha=0.1, early_stopping=True, hidden_layer_sizes=(30, 30),
#                 learning_rate_init=0.08099999999999999, max_iter=3000))],
#  'verbose': False,
#  'prep': ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                   ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#                                  ('recode categorical',
#                                   OneHotEncoder(handle_unknown='ignore',
#                                                 sparse=False),
#                                   ['Marca', 'Modelo', 'Combustible', 'Cambio',
#                                    'Provincia'])]),
#  'mlp': MLPRegressor(alpha=0.1, early_stopping=True, hidden_layer_sizes=(30, 30),
#               learning_rate_init=0.08099999999999999, max_iter=3000),
#  'prep__n_jobs': None,
#  'prep__remainder': 'drop',
#  'prep__sparse_threshold': 0.3,
#  'prep__transformer_weights': None,
#  'prep__transformers': [('rescale numeric',
#    StandardScaler(),
#    ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#   ('recode categorical',
#    OneHotEncoder(handle_unknown='ignore', sparse=False),
#    ['Marca', 'Modelo', 'Combustible', 'Cambio', 'Provincia'])],
#  'prep__verbose': False,
#  'prep__verbose_feature_names_out': True,
#  'prep__rescale numeric': StandardScaler(),
#  'prep__recode categorical': OneHotEncoder(handle_unknown='ignore', sparse=False),
#  'prep__rescale numeric__copy': True,
#  'prep__rescale numeric__with_mean': True,
#  'prep__rescale numeric__with_std': True,
#  'prep__recode categorical__categories': 'auto',
#  'prep__recode categorical__drop': None,
#  'prep__recode categorical__dtype': numpy.float64,
#  'prep__recode categorical__handle_unknown': 'ignore',
#  'prep__recode categorical__sparse': False,
#  'mlp__activation': 'relu',
#  'mlp__alpha': 0.1,
#  'mlp__batch_size': 'auto',
#  'mlp__beta_1': 0.9,
#  'mlp__beta_2': 0.999,
#  'mlp__early_stopping': True,
#  'mlp__epsilon': 1e-08,
#  'mlp__hidden_layer_sizes': (30, 30),
#  'mlp__learning_rate': 'constant',
#  'mlp__learning_rate_init': 0.08099999999999999,
#  'mlp__max_fun': 15000,
#  'mlp__max_iter': 3000,
#  'mlp__momentum': 0.9,
#  'mlp__n_iter_no_change': 10,
#  'mlp__nesterovs_momentum': True,
#  'mlp__power_t': 0.5,
#  'mlp__random_state': None,
#  'mlp__shuffle': True,
#  'mlp__solver': 'adam',
#  'mlp__tol': 0.0001,
#  'mlp__validation_fraction': 0.1,
#  'mlp__verbose': False,
#  'mlp__warm_start': False}

# %%
mse = mean_squared_error(y_true=y_test, y_pred=best_pipeline.predict(X_test))
mae = mean_absolute_error(y_true=y_test,y_pred=best_pipeline.predict(X_test))
rmse = np.sqrt(mse)

print("MSE: " + str(mse))
print("MAE: " +  str(mae))
print("RMSE: " +  str(rmse))
# Out:
# MSE: 6876688285.007955
# MAE: 6094.979050540462
# RMSE: 82925.79987559936

# %%
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, rs_mlp)

# %%
grid_mlp = {"mlp__hidden_layer_sizes": [(34,), (34,34),
                                        (36,),(36,36),
                                        (38,),(38,38)],
           "mlp__activation": ["relu"], 
           "mlp__solver": ["adam"], 
           "mlp__alpha": [0.05, 0.075, 0.1, 0.125], 
           "mlp__validation_fraction": [0.1], 
           "mlp__early_stopping": [True],    
           "mlp__max_iter": [3000],
           "mlp__learning_rate_init":list(np.arange(0.02, 0.1, step = 0.02)) 
           }

# %% [markdown]
# ##### KNR

# %% [markdown]
# Repetimos el mismo procedimiento de antes

# %%
best_randomsearch = all_rs_searchs["rs_knr"]
# Save the model best model
best_pipeline = best_randomsearch.best_estimator_
best_pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('prep',
#    ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                     ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#                                    ('recode categorical',
#                                     OneHotEncoder(handle_unknown='ignore',
#                                                   sparse=False),
#                                     ['Marca', 'Modelo', 'Combustible', 'Cambio',
#                                      'Provincia'])])),
#   ('knr', KNeighborsRegressor(weights='distance'))],
#  'verbose': False,
#  'prep': ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                   ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#                                  ('recode categorical',
#                                   OneHotEncoder(handle_unknown='ignore',
#                                                 sparse=False),
#                                   ['Marca', 'Modelo', 'Combustible', 'Cambio',
#                                    'Provincia'])]),
#  'knr': KNeighborsRegressor(weights='distance'),
#  'prep__n_jobs': None,
#  'prep__remainder': 'drop',
#  'prep__sparse_threshold': 0.3,
#  'prep__transformer_weights': None,
#  'prep__transformers': [('rescale numeric',
#    StandardScaler(),
#    ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#   ('recode categorical',
#    OneHotEncoder(handle_unknown='ignore', sparse=False),
#    ['Marca', 'Modelo', 'Combustible', 'Cambio', 'Provincia'])],
#  'prep__verbose': False,
#  'prep__verbose_feature_names_out': True,
#  'prep__rescale numeric': StandardScaler(),
#  'prep__recode categorical': OneHotEncoder(handle_unknown='ignore', sparse=False),
#  'prep__rescale numeric__copy': True,
#  'prep__rescale numeric__with_mean': True,
#  'prep__rescale numeric__with_std': True,
#  'prep__recode categorical__categories': 'auto',
#  'prep__recode categorical__drop': None,
#  'prep__recode categorical__dtype': numpy.float64,
#  'prep__recode categorical__handle_unknown': 'ignore',
#  'prep__recode categorical__sparse': False,
#  'knr__algorithm': 'auto',
#  'knr__leaf_size': 30,
#  'knr__metric': 'minkowski',
#  'knr__metric_params': None,
#  'knr__n_jobs': None,
#  'knr__n_neighbors': 5,
#  'knr__p': 2,
#  'knr__weights': 'distance'}

# %%
mse = mean_squared_error(y_true=y_test, y_pred=best_pipeline.predict(X_test))
mae = mean_absolute_error(y_true=y_test,y_pred=best_pipeline.predict(X_test))
rmse = np.sqrt(mse)

print("MSE: " + str(mse))
print("MAE: " +  str(mae))
print("RMSE: " +  str(rmse))
# Out:
# MSE: 6640470063.003835
# MAE: 5842.452833428845
# RMSE: 81489.07940947569

# %%
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, rs_knr)

# %% [markdown]
# A partir de los mejores valores del RandomSearch, fijamos la malla para el GridSearch que se usará afinando parámetros

# %%
grid_knr = {"knr__n_neighbors": list(np.arange(7, 20, step = 1)), 
                  "knr__weights": ["uniform","distance"]  
                  }

# %% [markdown]
# ##### DTR

# %% [markdown]
# Repetimos el mismo procedimiento de antes

# %%
best_randomsearch = all_rs_searchs["rs_dtr"]
# Save the model best model
best_pipeline = best_randomsearch.best_estimator_
best_pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('prep',
#    ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                     ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#                                    ('recode categorical',
#                                     OneHotEncoder(handle_unknown='ignore',
#                                                   sparse=False),
#                                     ['Marca', 'Modelo', 'Combustible', 'Cambio',
#                                      'Provincia'])])),
#   ('dtr', DecisionTreeRegressor(max_depth=18))],
#  'verbose': False,
#  'prep': ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                   ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#                                  ('recode categorical',
#                                   OneHotEncoder(handle_unknown='ignore',
#                                                 sparse=False),
#                                   ['Marca', 'Modelo', 'Combustible', 'Cambio',
#                                    'Provincia'])]),
#  'dtr': DecisionTreeRegressor(max_depth=18),
#  'prep__n_jobs': None,
#  'prep__remainder': 'drop',
#  'prep__sparse_threshold': 0.3,
#  'prep__transformer_weights': None,
#  'prep__transformers': [('rescale numeric',
#    StandardScaler(),
#    ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#   ('recode categorical',
#    OneHotEncoder(handle_unknown='ignore', sparse=False),
#    ['Marca', 'Modelo', 'Combustible', 'Cambio', 'Provincia'])],
#  'prep__verbose': False,
#  'prep__verbose_feature_names_out': True,
#  'prep__rescale numeric': StandardScaler(),
#  'prep__recode categorical': OneHotEncoder(handle_unknown='ignore', sparse=False),
#  'prep__rescale numeric__copy': True,
#  'prep__rescale numeric__with_mean': True,
#  'prep__rescale numeric__with_std': True,
#  'prep__recode categorical__categories': 'auto',
#  'prep__recode categorical__drop': None,
#  'prep__recode categorical__dtype': numpy.float64,
#  'prep__recode categorical__handle_unknown': 'ignore',
#  'prep__recode categorical__sparse': False,
#  'dtr__ccp_alpha': 0.0,
#  'dtr__criterion': 'squared_error',
#  'dtr__max_depth': 18,
#  'dtr__max_features': None,
#  'dtr__max_leaf_nodes': None,
#  'dtr__min_impurity_decrease': 0.0,
#  'dtr__min_samples_leaf': 1,
#  'dtr__min_samples_split': 2,
#  'dtr__min_weight_fraction_leaf': 0.0,
#  'dtr__random_state': None,
#  'dtr__splitter': 'best'}

# %%
mse = mean_squared_error(y_true=y_test, y_pred=best_pipeline.predict(X_test))
mae = mean_absolute_error(y_true=y_test,y_pred=best_pipeline.predict(X_test))
rmse = np.sqrt(mse)

print("MSE: " + str(mse))
print("MAE: " +  str(mae))
print("RMSE: " +  str(rmse))
# Out:
# MSE: 8695905260.938995
# MAE: 5976.891051994785
# RMSE: 93251.83784215192

# %%
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, rs_dtr)

# %% [markdown]
# A partir de los mejores valores del RandomSearch, fijamos la malla para el GridSearch que se usará afinando parámetros

# %%
grid_dtr = {"dtr__max_depth": list(np.arange(10, 30, step = 1)) 
              }

# %% [markdown]
# ##### RFR

# %% [markdown]
# Repetimos el mismo procedimiento que con el XGR

# %%
best_randomsearch = all_rs_searchs["rs_rfr"]
# Save the model best model
best_pipeline = best_randomsearch.best_estimator_
best_pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('prep',
#    ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                     ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#                                    ('recode categorical',
#                                     OneHotEncoder(handle_unknown='ignore',
#                                                   sparse=False),
#                                     ['Marca', 'Modelo', 'Combustible', 'Cambio',
#                                      'Provincia'])])),
#   ('rfr',
#    RandomForestRegressor(max_depth=40, max_features='sqrt', n_estimators=40))],
#  'verbose': False,
#  'prep': ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                   ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#                                  ('recode categorical',
#                                   OneHotEncoder(handle_unknown='ignore',
#                                                 sparse=False),
#                                   ['Marca', 'Modelo', 'Combustible', 'Cambio',
#                                    'Provincia'])]),
#  'rfr': RandomForestRegressor(max_depth=40, max_features='sqrt', n_estimators=40),
#  'prep__n_jobs': None,
#  'prep__remainder': 'drop',
#  'prep__sparse_threshold': 0.3,
#  'prep__transformer_weights': None,
#  'prep__transformers': [('rescale numeric',
#    StandardScaler(),
#    ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#   ('recode categorical',
#    OneHotEncoder(handle_unknown='ignore', sparse=False),
#    ['Marca', 'Modelo', 'Combustible', 'Cambio', 'Provincia'])],
#  'prep__verbose': False,
#  'prep__verbose_feature_names_out': True,
#  'prep__rescale numeric': StandardScaler(),
#  'prep__recode categorical': OneHotEncoder(handle_unknown='ignore', sparse=False),
#  'prep__rescale numeric__copy': True,
#  'prep__rescale numeric__with_mean': True,
#  'prep__rescale numeric__with_std': True,
#  'prep__recode categorical__categories': 'auto',
#  'prep__recode categorical__drop': None,
#  'prep__recode categorical__dtype': numpy.float64,
#  'prep__recode categorical__handle_unknown': 'ignore',
#  'prep__recode categorical__sparse': False,
#  'rfr__bootstrap': True,
#  'rfr__ccp_alpha': 0.0,
#  'rfr__criterion': 'squared_error',
#  'rfr__max_depth': 40,
#  'rfr__max_features': 'sqrt',
#  'rfr__max_leaf_nodes': None,
#  'rfr__max_samples': None,
#  'rfr__min_impurity_decrease': 0.0,
#  'rfr__min_samples_leaf': 1,
#  'rfr__min_samples_split': 2,
#  'rfr__min_weight_fraction_leaf': 0.0,
#  'rfr__n_estimators': 40,
#  'rfr__n_jobs': None,
#  'rfr__oob_score': False,
#  'rfr__random_state': None,
#  'rfr__verbose': 0,
#  'rfr__warm_start': False}

# %%
mse = mean_squared_error(y_true=y_test, y_pred=best_pipeline.predict(X_test))
mae = mean_absolute_error(y_true=y_test,y_pred=best_pipeline.predict(X_test))
rmse = np.sqrt(mse)

print("MSE: " + str(mse))
print("MAE: " +  str(mae))
print("RMSE: " +  str(rmse))
# Out:
# MSE: 7625463990.079324
# MAE: 7316.604800220953
# RMSE: 87323.9027419144

# %%
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, rs_rfr)

# %%
grid_rfr = {"rfr__n_estimators": [110, 120, 130], 
            "rfr__max_depth": [90, 100, 110], 
            "rfr__max_features": ["sqrt", 3] 
                     }

# %% [markdown]
# ### Finetuning de hiperparámetros

# %% [markdown]
# Para los 5 mejores modelos, en base a los resultados del RandomSearchCV, se hace un GridSearchCV con el objetivo de afinar los valores de los hiperparámetros

# %%
gs_xgr = GridSearchCV(xgr, 
                    grid_xgr, 
                    cv=5, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)

gs_rfr = GridSearchCV(rfr, 
                    grid_rfr, 
                    cv=5, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)

gs_dtr = GridSearchCV(dtr, 
                    grid_dtr, 
                    cv=5, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)

gs_knr = GridSearchCV(knr, 
                    grid_knr, 
                    cv=5, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)

gs_mlp = GridSearchCV(mlp,
                      grid_mlp,
                      cv=5,
                      scoring='neg_mean_absolute_error',
                      verbose=1,
                      n_jobs=-1)

# %%
all_gs_searchs = {"gs_xgr": gs_xgr,
                  "gs_rfr": gs_rfr,
                  "gs_dtr": gs_dtr,
                  "gs_knr": gs_knr,
                    "gs_mlp": gs_mlp
                    }

# %% [markdown]
# #### Entrenamiento de los modelos

# %%
for nombre, grid_search in all_gs_searchs.items():
    start = time.time()
    print("Haciendo Grid Search de %s..." % nombre)
    grid_search.fit(X_train, y_train)
    stop = time.time()
    print(f"Tiempo de entrenamiento: {stop - start} s")
# Out:
# Haciendo Grid Search de gs_xgr...
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [18:48:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Tiempo de entrenamiento: 6433.768270015717 s
# Haciendo Grid Search de gs_rfr...
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Tiempo de entrenamiento: 643.8975658416748 s
# Haciendo Grid Search de gs_dtr...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Tiempo de entrenamiento: 83.22622513771057 s
# Haciendo Grid Search de gs_knr...
# Fitting 5 folds for each of 26 candidates, totalling 130 fits
# Tiempo de entrenamiento: 618.2122623920441 s
# Haciendo Grid Search de gs_mlp...
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# Tiempo de entrenamiento: 6145.945820808411 s

# %% [markdown]
# #### Desempeño de los modelos

# %% [markdown]
# Evaluamos las métricas con el conjunto de test

# %% [markdown]
# ##### XGR

# %%
best_randomsearch = all_gs_searchs["gs_xgr"]
best_pipeline = best_randomsearch.best_estimator_

# %%
best_pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('prep',
#    ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                     ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#                                    ('recode categorical',
#                                     OneHotEncoder(handle_unknown='ignore',
#                                                   sparse=False),
#                                     ['Marca', 'Modelo', 'Combustible', 'Cambio',
#                                      'Provincia'])])),
#   ('xgr', XGBRegressor(learning_rate=0.15, max_depth=12, n_estimators=190))],
#  'verbose': False,
#  'prep': ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                   ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#                                  ('recode categorical',
#                                   OneHotEncoder(handle_unknown='ignore',
#                                                 sparse=False),
#                                   ['Marca', 'Modelo', 'Combustible', 'Cambio',
#                                    'Provincia'])]),
#  'xgr': XGBRegressor(learning_rate=0.15, max_depth=12, n_estimators=190),
#  'prep__n_jobs': None,
#  'prep__remainder': 'drop',
#  'prep__sparse_threshold': 0.3,
#  'prep__transformer_weights': None,
#  'prep__transformers': [('rescale numeric',
#    StandardScaler(),
#    ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#   ('recode categorical',
#    OneHotEncoder(handle_unknown='ignore', sparse=False),
#    ['Marca', 'Modelo', 'Combustible', 'Cambio', 'Provincia'])],
#  'prep__verbose': False,
#  'prep__verbose_feature_names_out': True,
#  'prep__rescale numeric': StandardScaler(),
#  'prep__recode categorical': OneHotEncoder(handle_unknown='ignore', sparse=False),
#  'prep__rescale numeric__copy': True,
#  'prep__rescale numeric__with_mean': True,
#  'prep__rescale numeric__with_std': True,
#  'prep__recode categorical__categories': 'auto',
#  'prep__recode categorical__drop': None,
#  'prep__recode categorical__dtype': numpy.float64,
#  'prep__recode categorical__handle_unknown': 'ignore',
#  'prep__recode categorical__sparse': False,
#  'xgr__base_score': 0.5,
#  'xgr__booster': 'gbtree',
#  'xgr__colsample_bylevel': 1,
#  'xgr__colsample_bynode': 1,
#  'xgr__colsample_bytree': 1,
#  'xgr__gamma': 0,
#  'xgr__importance_type': 'gain',
#  'xgr__learning_rate': 0.15,
#  'xgr__max_delta_step': 0,
#  'xgr__max_depth': 12,
#  'xgr__min_child_weight': 1,
#  'xgr__missing': None,
#  'xgr__n_estimators': 190,
#  'xgr__n_jobs': 1,
#  'xgr__nthread': None,
#  'xgr__objective': 'reg:linear',
#  'xgr__random_state': 0,
#  'xgr__reg_alpha': 0,
#  'xgr__reg_lambda': 1,
#  'xgr__scale_pos_weight': 1,
#  'xgr__seed': None,
#  'xgr__silent': None,
#  'xgr__subsample': 1,
#  'xgr__verbosity': 1}

# %%
mse = mean_squared_error(y_true=y_test, y_pred=best_pipeline.predict(X_test))
mae = mean_absolute_error(y_true=y_test,y_pred=best_pipeline.predict(X_test))
rmse = np.sqrt(mse)

print("MSE: " + str(mse))
print("MAE: " +  str(mae))
print("RMSE: " +  str(rmse))
# Out:
# MSE: 9361878830.732811
# MAE: 5566.062221923865
# RMSE: 96756.80250366281

# %%
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, gs_xgr)

# %%
plt.figure(figsize=(20,8))
xx = np.stack(i for i in range(y_test.shape[0]))
plt.plot(xx, y_test, c='r', label='Datos', marker='o')
plt.plot(xx, best_pipeline.predict(X_test), c='g', label='Predicción', marker='o')
plt.axis('tight')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3249: FutureWarning:
#
# arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.

# %% [markdown]
# ##### MLP

# %%
best_randomsearch = all_gs_searchs["gs_mlp"]
best_pipeline = best_randomsearch.best_estimator_

# %%
best_pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('prep',
#    ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                     ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#                                    ('recode categorical',
#                                     OneHotEncoder(handle_unknown='ignore',
#                                                   sparse=False),
#                                     ['Marca', 'Modelo', 'Combustible', 'Cambio',
#                                      'Provincia'])])),
#   ('mlp',
#    MLPRegressor(alpha=0.075, early_stopping=True, hidden_layer_sizes=(36, 36),
#                 learning_rate_init=0.04, max_iter=3000))],
#  'verbose': False,
#  'prep': ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                   ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#                                  ('recode categorical',
#                                   OneHotEncoder(handle_unknown='ignore',
#                                                 sparse=False),
#                                   ['Marca', 'Modelo', 'Combustible', 'Cambio',
#                                    'Provincia'])]),
#  'mlp': MLPRegressor(alpha=0.075, early_stopping=True, hidden_layer_sizes=(36, 36),
#               learning_rate_init=0.04, max_iter=3000),
#  'prep__n_jobs': None,
#  'prep__remainder': 'drop',
#  'prep__sparse_threshold': 0.3,
#  'prep__transformer_weights': None,
#  'prep__transformers': [('rescale numeric',
#    StandardScaler(),
#    ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#   ('recode categorical',
#    OneHotEncoder(handle_unknown='ignore', sparse=False),
#    ['Marca', 'Modelo', 'Combustible', 'Cambio', 'Provincia'])],
#  'prep__verbose': False,
#  'prep__verbose_feature_names_out': True,
#  'prep__rescale numeric': StandardScaler(),
#  'prep__recode categorical': OneHotEncoder(handle_unknown='ignore', sparse=False),
#  'prep__rescale numeric__copy': True,
#  'prep__rescale numeric__with_mean': True,
#  'prep__rescale numeric__with_std': True,
#  'prep__recode categorical__categories': 'auto',
#  'prep__recode categorical__drop': None,
#  'prep__recode categorical__dtype': numpy.float64,
#  'prep__recode categorical__handle_unknown': 'ignore',
#  'prep__recode categorical__sparse': False,
#  'mlp__activation': 'relu',
#  'mlp__alpha': 0.075,
#  'mlp__batch_size': 'auto',
#  'mlp__beta_1': 0.9,
#  'mlp__beta_2': 0.999,
#  'mlp__early_stopping': True,
#  'mlp__epsilon': 1e-08,
#  'mlp__hidden_layer_sizes': (36, 36),
#  'mlp__learning_rate': 'constant',
#  'mlp__learning_rate_init': 0.04,
#  'mlp__max_fun': 15000,
#  'mlp__max_iter': 3000,
#  'mlp__momentum': 0.9,
#  'mlp__n_iter_no_change': 10,
#  'mlp__nesterovs_momentum': True,
#  'mlp__power_t': 0.5,
#  'mlp__random_state': None,
#  'mlp__shuffle': True,
#  'mlp__solver': 'adam',
#  'mlp__tol': 0.0001,
#  'mlp__validation_fraction': 0.1,
#  'mlp__verbose': False,
#  'mlp__warm_start': False}

# %%
mse = mean_squared_error(y_true=y_test, y_pred=best_pipeline.predict(X_test))
mae = mean_absolute_error(y_true=y_test,y_pred=best_pipeline.predict(X_test))
rmse = np.sqrt(mse)

print("MSE: " + str(mse))
print("MAE: " +  str(mae))
print("RMSE: " +  str(rmse))
# Out:
# MSE: 5695001875.995861
# MAE: 6106.276055282047
# RMSE: 75465.23620844143

# %%
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, gs_mlp)

# %%
plt.figure(figsize=(20,8))
xx = np.stack(i for i in range(y_test.shape[0]))
plt.plot(xx, y_test, c='r', label='Datos', marker='o')
plt.plot(xx, best_pipeline.predict(X_test), c='g', label='Predicción', marker='o')
plt.axis('tight')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3249: FutureWarning:
#
# arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.

# %% [markdown]
# El tiempo de ejecucción es muy alto. ¿Esto justifica reducir las características que aporten información?

# %% [markdown]
# ##### KNR

# %%
best_randomsearch = all_gs_searchs["gs_knr"]
best_pipeline = best_randomsearch.best_estimator_

# %%
best_pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('prep',
#    ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                     ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#                                    ('recode categorical',
#                                     OneHotEncoder(handle_unknown='ignore',
#                                                   sparse=False),
#                                     ['Marca', 'Modelo', 'Combustible', 'Cambio',
#                                      'Provincia'])])),
#   ('knr', KNeighborsRegressor(n_neighbors=8, weights='distance'))],
#  'verbose': False,
#  'prep': ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                   ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#                                  ('recode categorical',
#                                   OneHotEncoder(handle_unknown='ignore',
#                                                 sparse=False),
#                                   ['Marca', 'Modelo', 'Combustible', 'Cambio',
#                                    'Provincia'])]),
#  'knr': KNeighborsRegressor(n_neighbors=8, weights='distance'),
#  'prep__n_jobs': None,
#  'prep__remainder': 'drop',
#  'prep__sparse_threshold': 0.3,
#  'prep__transformer_weights': None,
#  'prep__transformers': [('rescale numeric',
#    StandardScaler(),
#    ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#   ('recode categorical',
#    OneHotEncoder(handle_unknown='ignore', sparse=False),
#    ['Marca', 'Modelo', 'Combustible', 'Cambio', 'Provincia'])],
#  'prep__verbose': False,
#  'prep__verbose_feature_names_out': True,
#  'prep__rescale numeric': StandardScaler(),
#  'prep__recode categorical': OneHotEncoder(handle_unknown='ignore', sparse=False),
#  'prep__rescale numeric__copy': True,
#  'prep__rescale numeric__with_mean': True,
#  'prep__rescale numeric__with_std': True,
#  'prep__recode categorical__categories': 'auto',
#  'prep__recode categorical__drop': None,
#  'prep__recode categorical__dtype': numpy.float64,
#  'prep__recode categorical__handle_unknown': 'ignore',
#  'prep__recode categorical__sparse': False,
#  'knr__algorithm': 'auto',
#  'knr__leaf_size': 30,
#  'knr__metric': 'minkowski',
#  'knr__metric_params': None,
#  'knr__n_jobs': None,
#  'knr__n_neighbors': 8,
#  'knr__p': 2,
#  'knr__weights': 'distance'}

# %%
mse = mean_squared_error(y_true=y_test, y_pred=best_pipeline.predict(X_test))
mae = mean_absolute_error(y_true=y_test,y_pred=best_pipeline.predict(X_test))
rmse = np.sqrt(mse)

print("MSE: " + str(mse))
print("MAE: " +  str(mae))
print("RMSE: " +  str(rmse))
# Out:
# MSE: 6708181628.6832
# MAE: 5818.153472318448
# RMSE: 81903.48972225298

# %%
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, gs_knr)

# %%
plt.figure(figsize=(20,8))
xx = np.stack(i for i in range(y_test.shape[0]))
plt.plot(xx, y_test, c='r', label='Datos', marker='o')
plt.plot(xx, best_pipeline.predict(X_test), c='g', label='Predicción', marker='o')
plt.axis('tight')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3249: FutureWarning:
#
# arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.

# %% [markdown]
# ##### DTR

# %%
best_randomsearch = all_gs_searchs["gs_dtr"]
best_pipeline = best_randomsearch.best_estimator_

# %%
best_pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('prep',
#    ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                     ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#                                    ('recode categorical',
#                                     OneHotEncoder(handle_unknown='ignore',
#                                                   sparse=False),
#                                     ['Marca', 'Modelo', 'Combustible', 'Cambio',
#                                      'Provincia'])])),
#   ('dtr', DecisionTreeRegressor(max_depth=24))],
#  'verbose': False,
#  'prep': ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                   ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#                                  ('recode categorical',
#                                   OneHotEncoder(handle_unknown='ignore',
#                                                 sparse=False),
#                                   ['Marca', 'Modelo', 'Combustible', 'Cambio',
#                                    'Provincia'])]),
#  'dtr': DecisionTreeRegressor(max_depth=24),
#  'prep__n_jobs': None,
#  'prep__remainder': 'drop',
#  'prep__sparse_threshold': 0.3,
#  'prep__transformer_weights': None,
#  'prep__transformers': [('rescale numeric',
#    StandardScaler(),
#    ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#   ('recode categorical',
#    OneHotEncoder(handle_unknown='ignore', sparse=False),
#    ['Marca', 'Modelo', 'Combustible', 'Cambio', 'Provincia'])],
#  'prep__verbose': False,
#  'prep__verbose_feature_names_out': True,
#  'prep__rescale numeric': StandardScaler(),
#  'prep__recode categorical': OneHotEncoder(handle_unknown='ignore', sparse=False),
#  'prep__rescale numeric__copy': True,
#  'prep__rescale numeric__with_mean': True,
#  'prep__rescale numeric__with_std': True,
#  'prep__recode categorical__categories': 'auto',
#  'prep__recode categorical__drop': None,
#  'prep__recode categorical__dtype': numpy.float64,
#  'prep__recode categorical__handle_unknown': 'ignore',
#  'prep__recode categorical__sparse': False,
#  'dtr__ccp_alpha': 0.0,
#  'dtr__criterion': 'squared_error',
#  'dtr__max_depth': 24,
#  'dtr__max_features': None,
#  'dtr__max_leaf_nodes': None,
#  'dtr__min_impurity_decrease': 0.0,
#  'dtr__min_samples_leaf': 1,
#  'dtr__min_samples_split': 2,
#  'dtr__min_weight_fraction_leaf': 0.0,
#  'dtr__random_state': None,
#  'dtr__splitter': 'best'}

# %%
mse = mean_squared_error(y_true=y_test, y_pred=best_pipeline.predict(X_test))
mae = mean_absolute_error(y_true=y_test,y_pred=best_pipeline.predict(X_test))
rmse = np.sqrt(mse)

print("MSE: " + str(mse))
print("MAE: " +  str(mae))
print("RMSE: " +  str(rmse))
# Out:
# MSE: 8346220478.836336
# MAE: 5870.865408656972
# RMSE: 91357.6514520614

# %%
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, gs_dtr)

# %%
plt.figure(figsize=(20,8))
xx = np.stack(i for i in range(y_test.shape[0]))
plt.plot(xx, y_test, c='r', label='Datos', marker='o')
plt.plot(xx, best_pipeline.predict(X_test), c='g', label='Predicción', marker='o')
plt.axis('tight')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3249: FutureWarning:
#
# arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.

# %% [markdown]
# ##### RFR

# %%
best_randomsearch = all_gs_searchs["gs_rfr"]
best_pipeline = best_randomsearch.best_estimator_

# %%
best_pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('prep',
#    ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                     ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#                                    ('recode categorical',
#                                     OneHotEncoder(handle_unknown='ignore',
#                                                   sparse=False),
#                                     ['Marca', 'Modelo', 'Combustible', 'Cambio',
#                                      'Provincia'])])),
#   ('rfr',
#    RandomForestRegressor(max_depth=100, max_features='sqrt', n_estimators=130))],
#  'verbose': False,
#  'prep': ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                   ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#                                  ('recode categorical',
#                                   OneHotEncoder(handle_unknown='ignore',
#                                                 sparse=False),
#                                   ['Marca', 'Modelo', 'Combustible', 'Cambio',
#                                    'Provincia'])]),
#  'rfr': RandomForestRegressor(max_depth=100, max_features='sqrt', n_estimators=130),
#  'prep__n_jobs': None,
#  'prep__remainder': 'drop',
#  'prep__sparse_threshold': 0.3,
#  'prep__transformer_weights': None,
#  'prep__transformers': [('rescale numeric',
#    StandardScaler(),
#    ['Año', 'Kilometraje', 'Potencia', 'Fotos']),
#   ('recode categorical',
#    OneHotEncoder(handle_unknown='ignore', sparse=False),
#    ['Marca', 'Modelo', 'Combustible', 'Cambio', 'Provincia'])],
#  'prep__verbose': False,
#  'prep__verbose_feature_names_out': True,
#  'prep__rescale numeric': StandardScaler(),
#  'prep__recode categorical': OneHotEncoder(handle_unknown='ignore', sparse=False),
#  'prep__rescale numeric__copy': True,
#  'prep__rescale numeric__with_mean': True,
#  'prep__rescale numeric__with_std': True,
#  'prep__recode categorical__categories': 'auto',
#  'prep__recode categorical__drop': None,
#  'prep__recode categorical__dtype': numpy.float64,
#  'prep__recode categorical__handle_unknown': 'ignore',
#  'prep__recode categorical__sparse': False,
#  'rfr__bootstrap': True,
#  'rfr__ccp_alpha': 0.0,
#  'rfr__criterion': 'squared_error',
#  'rfr__max_depth': 100,
#  'rfr__max_features': 'sqrt',
#  'rfr__max_leaf_nodes': None,
#  'rfr__max_samples': None,
#  'rfr__min_impurity_decrease': 0.0,
#  'rfr__min_samples_leaf': 1,
#  'rfr__min_samples_split': 2,
#  'rfr__min_weight_fraction_leaf': 0.0,
#  'rfr__n_estimators': 130,
#  'rfr__n_jobs': None,
#  'rfr__oob_score': False,
#  'rfr__random_state': None,
#  'rfr__verbose': 0,
#  'rfr__warm_start': False}

# %%
mse = mean_squared_error(y_true=y_test, y_pred=best_pipeline.predict(X_test))
mae = mean_absolute_error(y_true=y_test,y_pred=best_pipeline.predict(X_test))
rmse = np.sqrt(mse)

print("MSE: " + str(mse))
print("MAE: " +  str(mae))
print("RMSE: " +  str(rmse))
# Out:
# MSE: 7411353385.04336
# MAE: 5270.971838384628
# RMSE: 86089.21758875126

# %%
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, gs_rfr)

# %%
plt.figure(figsize=(20,8))
xx = np.stack(i for i in range(y_test.shape[0]))
plt.plot(xx, y_test, c='r', label='Datos', marker='o')
plt.plot(xx, best_pipeline.predict(X_test), c='g', label='Predicción', marker='o')
plt.axis('tight')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3249: FutureWarning:
#
# arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.

# %% [markdown]
# ## Modelado de predicción de precio usando FeatureSelect para usar sólo las características más importantes

# %% [markdown]
# Vamos a comprobar si es posible obtener buenos resultados en la predicción eliminando las características que tienen poca importancia.
#
# Antes de hacer uso de FeatureSelector es necesario hacer la división entre train/test, para usar la selección de características en el conjunto de entrenamiento
#
# No es preciso hace one hot enconding, ya que lo hace el propio método

# %% [markdown]
# ### Preprocesado

# %% [markdown]
# Ya tenemos previamente separados el dataframe en dos conjuntos de datos, utilizando un 25% de los datos para test y el resto para entrenar

# %% [markdown]
# Cargamos FeatureSelector

# %%
fs = FeatureSelector(data = X_train , labels = y_train)

# %%
fs.identify_zero_importance(task = 'regression', eval_metric = 'l2', 
                            n_iterations = 10, early_stopping = True)
# Out:
# Training Gradient Boosting Model
#
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [172]	valid_0's l2: 4.47838e+09	valid_0's l2: 4.47838e+09
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [195]	valid_0's l2: 4.78962e+09	valid_0's l2: 4.78962e+09
# Training until validation scores don't improve for 100 rounds.
# Did not meet early stopping. Best iteration is:
# [996]	valid_0's l2: 6.39567e+09	valid_0's l2: 6.39567e+09
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [27]	valid_0's l2: 1.02928e+09	valid_0's l2: 1.02928e+09
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [433]	valid_0's l2: 7.90177e+08	valid_0's l2: 7.90177e+08
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [109]	valid_0's l2: 6.53036e+09	valid_0's l2: 6.53036e+09
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [208]	valid_0's l2: 1.3623e+09	valid_0's l2: 1.3623e+09
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [69]	valid_0's l2: 4.5481e+09	valid_0's l2: 4.5481e+09
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [30]	valid_0's l2: 5.91716e+09	valid_0's l2: 5.91716e+09
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [42]	valid_0's l2: 1.97487e+09	valid_0's l2: 1.97487e+09
#
# 906 features with zero importance after one-hot encoding.

# %% [markdown]
# El número de variables con importancia cero cambia ligeramente en función del número de iteraciones (es un proceso con una cierta estocasticidad)

# %%
sns.set(style="white")
fs.plot_feature_importances(threshold = 0.99, plot_n = 20)
# Out:
# 86 features required for 0.99 of cumulative importance

# %%
fs.feature_importances.head(30)
# Out:
#                  feature  importance  normalized_importance  \
# 0               Potencia      1929.0               0.281894
# 1            Kilometraje      1116.1               0.163101
# 2                    Año       896.0               0.130937
# 3                  Fotos       755.6               0.110419
# 4          Marca_FERRARI       232.4               0.033962
# 5         Marca_MASERATI       130.5               0.019071
# 6       Provincia_Madrid       123.0               0.017975
# 7         Modelo_VANTAGE       119.8               0.017507
# 8     Modelo_CONTINENTAL       112.8               0.016484
# 9      Marca_LAMBORGHINI       100.5               0.014687
# 10           Marca_DODGE        95.7               0.013985
# 11            Modelo_488        92.8               0.013561
# 12      Provincia_Murcia        78.6               0.011486
# 13            Modelo_911        76.0               0.011106
# 14      Modelo_AVENTADOR        70.3               0.010273
# 15         Marca_PORSCHE        54.3               0.007935
# 16     Cambio_Automatico        51.2               0.007482
# 17   Marca_MERCEDES-BENZ        46.9               0.006854
# 18      Modelo_GIULIETTA        37.5               0.005480
# 19             Modelo_F8        37.0               0.005407
# 20    Combustible_Diesel        36.8               0.005378
# 21         Marca_BENTLEY        36.5               0.005334
# 22    Marca_ASTON MARTIN        35.9               0.005246
# 23           Modelo_URUS        34.3               0.005012
# 24        Modelo_CLASE G        33.8               0.004939
# 25        Modelo_CLASE S        31.3               0.004574
# 26  Combustible_Gasolina        30.7               0.004486
# 27            Marca_AUDI        30.6               0.004472
# 28      Marca_LAND-ROVER        21.9               0.003200
# 29             Marca_BMW        21.4               0.003127
#
#     cumulative_importance
# 0                0.281894
# 1                0.444995
# 2                0.575932
# 3                0.686351
# 4                0.720313
# 5                0.739383
# 6                0.757358
# 7                0.774865
# 8                0.791349
# 9                0.806035
# 10               0.820020
# 11               0.833582
# 12               0.845068
# 13               0.856174
# 14               0.866447
# 15               0.874383
# 16               0.881865
# 17               0.888718
# 18               0.894198
# 19               0.899605
# 20               0.904983
# 21               0.910317
# 22               0.915563
# 23               0.920576
# 24               0.925515
# 25               0.930089
# 26               0.934575
# 27               0.939047
# 28               0.942248
# 29               0.945375

# %% [markdown]
# Se observa que la característica más importante es la potencia del vehículo, seguido del kilometraje. El número de fotos es la variable numérica menos relevante.

# %% [markdown]
# También es posible ver las características que tienen poca relevancia (destacar que este método también es estocástico)

# %%
fs.identify_low_importance(cumulative_importance = 0.99)
# Out:
# 85 features required for cumulative importance of 0.99 after one hot encoding.
# 1008 features do not contribute to cumulative importance of 0.99.

# %% [markdown]
# Es decir, que entre todas las caracaterísticas, entorno a 965 (según el método que se seleccione), se puede cubrir el 99% de la importancia acumulada.
#
# Vemos las variables con poca importancia

# %%
low_importance_features = fs.ops['low_importance']
print("Total de características con poca importancia:", len(low_importance_features))
print(low_importance_features[:965])
# Out:
# Total de características con poca importancia: 1008
# ['Modelo_SERIE 1', 'Modelo_Z3', 'Modelo_MONDEO', 'Provincia_Palmas (Las)', 'Modelo_GLC COUPÉ', 'Marca_SKODA', 'Marca_RENAULT', 'Modelo_V90', 'Modelo_508', 'Marca_FIAT', 'Modelo_X2', 'Marca_LEXUS', 'Modelo_XC60', 'Modelo_MÉGANE', 'Modelo_CLASE A', 'Modelo_CLASE B', 'Modelo_SERIE 3', 'Provincia_Asturias', 'Modelo_I30', 'Modelo_CITAN', 'Modelo_TOUAREG', 'Modelo_JIMNY', 'Marca_CUPRA', 'Marca_SSANGYONG', 'Marca_TOYOTA', 'Modelo_XC40', 'Modelo_A6', 'Cambio_Manual', 'Marca_DS', 'Modelo_QASHQAI', 'Modelo_CLASE SL', 'Marca_SEAT', 'Marca_DACIA', 'Modelo_CX-3', 'Modelo_TAYCAN', 'Modelo_X1', 'Modelo_TUCSON', 'Modelo_SERIE 2', 'Modelo_AURIS', 'Marca_ALFA ROMEO', 'Provincia_Málaga', 'Modelo_Q2', 'Marca_SUBARU', 'Modelo_X3', 'Modelo_COROLLA', 'Modelo_300', 'Modelo_PASSAT', 'Modelo_INSIGNIA', 'Marca_HYUNDAI', 'Provincia_Albacete', 'Modelo_TERRANO', 'Modelo_SF90', 'Modelo_NX', 'Modelo_Z4', 'Marca_PEUGEOT', 'Modelo_5008', 'Modelo_ARTEON', 'Modelo_C-ELYSÉE', 'Modelo_CEED', 'Modelo_CRAFTER', 'Marca_VOLVO', 'Modelo_OCTAVIA', 'Modelo_BEETLE', 'Modelo_KORANDO', 'Modelo_CLASE GLB', 'Provincia_Sevilla', 'Modelo_YARIS', 'Modelo_F-TYPE', 'Modelo_208', 'Modelo_CAYENNE', 'Modelo_GOLF', 'Modelo_C-HR', 'Marca_IVECO', 'Provincia_Valencia', 'Modelo_IS', 'Modelo_QUATTROPORTE', 'Modelo_SPORTAGE', 'Marca_KIA', 'Modelo_CR-V', 'Modelo_A7', 'Modelo_T-ROC', 'Modelo_ASTRA', 'Modelo_POLO', 'Modelo_A5', 'Modelo_IBIZA', 'Modelo_RENEGADE', 'Modelo_A4', 'Modelo_PICANTO', 'Modelo_CLA', 'Modelo_SERIE 7', 'Modelo_GRANDLAND', 'Modelo_GIULIA', 'Modelo_C-MAX', 'Combustible_GLP', 'Modelo_SUPERB', 'Modelo_A3', 'Modelo_MODEL S', 'Modelo_CAPTUR', 'Modelo_EQC', 'Modelo_CLIO', 'Modelo_COUNTRYMAN', 'Modelo_355', 'Modelo_350Z', 'Modelo_33', 'Modelo_323', 'Modelo_121', 'Modelo_107', 'Modelo_360', 'Modelo_106', 'Marca_LINCOLN', 'Marca_LEVC', 'Modelo_108', 'Modelo_370Z', 'Modelo_4-RUNNER', 'Marca_LDV', 'Modelo_400', 'Modelo_4007', 'Modelo_4008', 'Modelo_405', 'Modelo_406', 'Modelo_407', 'Modelo_440', 'Modelo_45', 'Modelo_456', 'Modelo_458', 'Modelo_4', 'Marca_LANCIA', 'Marca_BUGATTI', 'Marca_KARMA', 'Marca_MAHINDRA', 'Modelo_570S', 'Marca_LOTUS', 'Marca_ABARTH', 'Marca_ALPINA', 'Marca_ALPINE', 'Marca_AUSTIN', 'Marca_BERTONE', 'Modelo_460', 'Marca_CHRYSLER', 'Marca_CORVETTE', 'Marca_KTM', 'Marca_DAEWOO', 'Marca_DFSK', 'Marca_DR', 'Marca_GALLOPER', 'Marca_GMC', 'Marca_HONDA', 'Marca_HUMMER', 'Marca_HURTAN', 'Marca_INFINITI', 'Marca_INVICTA', 'Marca_ISUZU', 'Marca_JEEP', 'Marca_DAIHATSU', 'Modelo_480', 'Modelo_180D', 'Modelo_500L', 'Modelo_2CV', 'Modelo_3', 'Modelo_300 GT', 'Modelo_3000', 'Modelo_3008 HYBRID', 'Modelo_300C', 'Modelo_CARENS', 'Modelo_CARINA E', 'Modelo_CARISMA', 'Modelo_FLYING', 'Modelo_FORESTER', 'Modelo_280', 'Modelo_FORFOUR', 'Modelo_FORTWO', 'Modelo_FR-V', 'Modelo_FREECLIMBER', 'Modelo_FREELANDER', 'Modelo_FREEMONT', 'Modelo_FRONTERA', 'Modelo_FULLBACK', 'Modelo_FUSION', 'Modelo_FX', 'Modelo_G', 'Modelo_G01F', 'Modelo_FORMENTOR', 'Modelo_260', 'Modelo_25', 'Modelo_230', 'Modelo_500X', 'Modelo_505', 'Modelo_508 HYBRID', 'Modelo_550', 'Modelo_570GT', 'Modelo_309', 'Modelo_307', 'Modelo_306', 'Modelo_205', 'Modelo_124', 'Modelo_140D', 'Modelo_146', 'Modelo_147', 'Modelo_156', 'Modelo_159', 'Modelo_164', 'Marca_MAYBACH', 'Modelo_19', 'Modelo_190', 'Modelo_200', 'Modelo_2008', 'Modelo_206', 'Modelo_300M', 'Modelo_207', 'Modelo_220', 'Modelo_500', 'Modelo_100D', 'Modelo_A1', 'Modelo_100 NX', 'Modelo_C4 AIRCROSS', 'Modelo_C4 CACTUS', 'Modelo_C4 PICASSO', 'Modelo_C4 SEDÁN', 'Modelo_C4 SPACETOURER', 'Modelo_C5', 'Modelo_C5 AIRCROSS', 'Modelo_C5 AIRCROSS HYBRID', 'Modelo_C6', 'Modelo_C7', 'Modelo_C70', 'Modelo_C4', 'Modelo_C8', 'Modelo_CABRIOLET', 'Modelo_CABSTAR', 'Modelo_CALIBER', 'Modelo_CALIBRA', 'Modelo_CAMION', 'Modelo_CAMRY', 'Modelo_CANTER', 'Modelo_CAPRI', 'Modelo_CAPTIVA', 'Modelo_C3', 'Modelo_C1', 'Modelo_CABRIO', 'Modelo_C30', 'Modelo_C3 PLURIEL', 'Modelo_C3 PICASSO', 'Modelo_718', 'Modelo_720S', 'Modelo_740', 'Modelo_75', 'Modelo_765LT', 'Modelo_80', 'Modelo_806', 'Mod ...

# %% [markdown]
# Vemos también si hay variables con muy alta correlación, por si fuera necesario eliminarlas

# %%
fs.identify_all(selection_params = {'missing_threshold': 0.6, 'correlation_threshold': 0.98, 
                                    'task': 'regression', 'eval_metric': 'l2', 
                                     'cumulative_importance': 0.99})
# Out:
# 0 features with greater than 0.60 missing values.
#
# 0 features with a single unique value.
#
# 0 features with a correlation magnitude greater than 0.98.
#
# Training Gradient Boosting Model
#
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [586]	valid_0's l2: 2.15518e+09	valid_0's l2: 2.15518e+09
# Training until validation scores don't improve for 100 rounds.
# Did not meet early stopping. Best iteration is:
# [999]	valid_0's l2: 2.8373e+09	valid_0's l2: 2.8373e+09
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [536]	valid_0's l2: 2.4346e+09	valid_0's l2: 2.4346e+09
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [334]	valid_0's l2: 1.81939e+09	valid_0's l2: 1.81939e+09
# Training until validation scores don't improve for 100 rounds.
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's l2: 2.47944e+09	valid_0's l2: 2.47944e+09
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [640]	valid_0's l2: 7.71122e+09	valid_0's l2: 7.71122e+09
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [21]	valid_0's l2: 2.65658e+09	valid_0's l2: 2.65658e+09
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [340]	valid_0's l2: 1.36929e+09	valid_0's l2: 1.36929e+09
# Training until validation scores don't improve for 100 rounds.
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's l2: 2.3656e+09	valid_0's l2: 2.3656e+09
# Training until validation scores don't improve for 100 rounds.
# Did not meet early stopping. Best iteration is:
# [999]	valid_0's l2: 3.84901e+09	valid_0's l2: 3.84901e+09
#
# 874 features with zero importance after one-hot encoding.
#
# 107 features required for cumulative importance of 0.99 after one hot encoding.
# 986 features do not contribute to cumulative importance of 0.99.
#
# 986 total features out of 1098 identified for removal after one-hot encoding.

# %% [markdown]
# Vemos que no hay variables con missing values ni correlacionadas.
# Vamos a generar ahora un datraframe en le que se eliminen las variables que tienen poca o ninguna importancia

# %%
df_2mano_fs = fs.remove(methods = 'all', keep_one_hot = True)
# Out:
# ['zero_importance', 'low_importance', 'missing', 'single_unique', 'collinear'] methods have been run
#
# Removed 986 features.

# %% [markdown]
# Podemos ver la reducción de características que se ha realizado al usar FeatureSelect

# %%
print( "Dataframe original con one hot encoding", df_2mano_dummies.shape)
print( "Dataframe modificado con FeatureSelect", df_2mano_fs.shape)
# Out:
# Dataframe original con one hot encoding (79107, 1127)
# Dataframe modificado con FeatureSelect (59330, 112)

# %% [markdown]
# Se observa que se ha pasado de 1127 características a 121

# %% [markdown]
# Mostramos las características que finalmente hemos dejado

# %%
lista = list(df_2mano_fs.columns)
lista.insert(0, 'Precio')
originales = ['Marca', 'Modelo', 'Combustible', 'Cambio', 'Provincia']
lista = [e for e in lista if e not in originales]
print(lista)
# Out:
# ['Precio', 'Marca_ASTON MARTIN', 'Marca_AUDI', 'Marca_BENTLEY', 'Marca_BMW', 'Marca_CADILLAC', 'Marca_CHEVROLET', 'Marca_CITROEN', 'Marca_DACIA', 'Marca_DODGE', 'Marca_FERRARI', 'Marca_FIAT', 'Marca_FORD', 'Marca_LAMBORGHINI', 'Marca_LAND-ROVER', 'Marca_LEXUS', 'Marca_MASERATI', 'Marca_MERCEDES-BENZ', 'Marca_MINI', 'Marca_OPEL', 'Marca_PORSCHE', 'Marca_RENAULT', 'Marca_SEAT', 'Marca_SKODA', 'Marca_SSANGYONG', 'Marca_TESLA', 'Marca_TOYOTA', 'Marca_VOLKSWAGEN', 'Modelo_3008', 'Modelo_308', 'Modelo_488', 'Modelo_508', 'Modelo_911', 'Modelo_AMG', 'Modelo_AURIS', 'Modelo_AVENTADOR', 'Modelo_CALIFORNIA', 'Modelo_CARAVELLE', 'Modelo_CITAN', 'Modelo_CLASE A', 'Modelo_CLASE C', 'Modelo_CLASE G', 'Modelo_CLASE GLC', 'Modelo_CLASE GLE', 'Modelo_CLASE GLE COUPÉ', 'Modelo_CLASE S', 'Modelo_CLASE V', 'Modelo_CONTINENTAL', 'Modelo_DEFENDER', 'Modelo_E-PACE', 'Modelo_E-TRON', 'Modelo_F-PACE', 'Modelo_F8', 'Modelo_FOCUS', 'Modelo_GHIBLI', 'Modelo_GIULIETTA', 'Modelo_GLC COUPÉ', 'Modelo_HURACÁN', 'Modelo_I30', 'Modelo_IMPREZA', 'Modelo_JIMNY', 'Modelo_LAND CRUISER', 'Modelo_LEON', 'Modelo_LEVANTE', 'Modelo_MONDEO', 'Modelo_MONTERO', 'Modelo_MULTIVAN', 'Modelo_MUSTANG', 'Modelo_MÉGANE', 'Modelo_PANAMERA', 'Modelo_Q3', 'Modelo_Q5', 'Modelo_Q7', 'Modelo_Q8', 'Modelo_R8', 'Modelo_RANGE ROVER', 'Modelo_SERIE 1', 'Modelo_SERIE 5', 'Modelo_SF90', 'Modelo_TIGUAN', 'Modelo_TIPO', 'Modelo_TRANSPORTER', 'Modelo_URUS', 'Modelo_V90', 'Modelo_VANTAGE', 'Modelo_VIANO', 'Modelo_WRANGLER', 'Modelo_X2', 'Modelo_X4', 'Modelo_X5', 'Modelo_X6', 'Modelo_XC40', 'Modelo_XC60', 'Modelo_XC90', 'Combustible_Diesel', 'Combustible_Electrico', 'Combustible_Gasolina', 'Combustible_Hibrido', 'Cambio_Automatico', 'Provincia_Barcelona', 'Provincia_Madrid', 'Provincia_Murcia', 'Provincia_Palmas (Las)', 'Provincia_Toledo', 'Año', 'Kilometraje', 'Potencia', 'Fotos']

# %% [markdown]
# Modificamos el dataframe original para quedarnos sólo con las columnas que tienen importancia y la variable objetivo

# %%
df_2mano_dummies = df_2mano_dummies[lista]

# %% [markdown]
# Exportamos el dataframe para tener una copia

# %%
df_2mano_dummies.to_excel(path+"df_2mano_dummies.xlsx", header=True)

# %%
#df_2mano_dummies = pd.read_excel(path+'df_2mano_dummies.xlsx', index_col=[0])
#Para poder trabajar en local

# %% [markdown]
# Separamos dos conjuntos de datos, utilizando un 25% de los datos para test y el resto para entrenar

# %%
X_train, X_test, y_train, y_test = train_test_split(
                                        df_2mano_dummies.drop(columns = target),
                                        df_2mano_dummies[target],
                                        test_size=0.25,
                                        random_state = 123
                                    )

print("Dimensiones del dataframe original",df_2mano_dummies.shape)
print("Dimensiones del dataframe sin variable objetivo para train", X_train.shape)
print("variable objetivo para train", y_train.shape)
print("Dimensiones del dataframe sin variable objetivo para test", X_test.shape)
print("variable objetivo para test", y_test.shape)
# Out:
# Dimensiones del dataframe original (79107, 108)
# Dimensiones del dataframe sin variable objetivo para train (59330, 107)
# variable objetivo para train (59330,)
# Dimensiones del dataframe sin variable objetivo para test (19777, 107)
# variable objetivo para test (19777,)

# %% [markdown]
# Se hace un reset de índices

# %%
X_train.reset_index(drop = True, inplace = True)
X_test.reset_index(drop = True, inplace = True)
y_train.reset_index(drop = True, inplace = True)
y_test.reset_index(drop = True, inplace = True)

# %% [markdown]
# Creamos un transformer para estandarizar las variables numéricas (ya no hay variables categoricas al haber hecho el one hot enconding previamente para el dataframe df_2mano_dummies)

# %%
data_transformer = ColumnTransformer(
  transformers = [
    ('rescale numeric', preprocessing.StandardScaler(), num_feat),    
    ])

# %% [markdown]
# ### Creación del pipeline con los modelos

# %% [markdown]
# Creamos el pipeline que aplica la transformación y asigna el modelo a usar.
# Realmente, para los modelos tipo árbol (dtr, rfr y gbr) no sería necesario estandarizar (pero tampoco pasa nada si se hace)

# %%
dtr = Pipeline(steps = [("prep", data_transformer), ('dtr', DecisionTreeRegressor())])
rfr = Pipeline(steps = [("prep", data_transformer), ('rfr', RandomForestRegressor())])
gbr = Pipeline(steps = [("prep", data_transformer), ('gbr', GradientBoostingRegressor())])
lr = Pipeline(steps=[("prep", data_transformer), ("lr",LinearRegression())])
ridge = Pipeline(steps=[("prep", data_transformer), ("ridge",Ridge())])
lasso = Pipeline(steps=[("prep", data_transformer), ("lasso",Lasso())])
knr = Pipeline(steps=[("prep", data_transformer), ("knr",KNeighborsRegressor())])
#svr = Pipeline(steps=[("prep", data_transformer), ("svr",SVR())]) No acaba nunca de coverger
lsvr= Pipeline(steps=[("prep", data_transformer), ("lsvr",LinearSVR())])
mlp = Pipeline(steps=[("prep", data_transformer), ("mlp",MLPRegressor())])
xgr = Pipeline(steps=[("prep", data_transformer), ("xgr",XGBRegressor())])

# %% [markdown]
# ### Búsqueda inicial de hiperparámetros: RandomSearch

# %% [markdown]
# Se utiliza inicialmente la técnica de RandomSearchCV, para buscar unos parámetros iniciales que luego se puedan afinar con GridSearchCV

# %%
# Arbol de decisión
grid_rs_dtr = {"dtr__max_depth": list(np.arange(2, 20, step = 2)) 
              }
# Random Forest
grid_rs_rfr = {"rfr__n_estimators": list(np.arange(10, 100, step = 10)), 
                     
                     "rfr__max_depth": list(np.arange(10, 50, step = 10)), 
                      
                     "rfr__max_features": ["sqrt", 3, 4] 
                     }
# Gradient Boosting
grid_rs_gbr = {"gbr__loss": ["squared_error"],
                          "gbr__learning_rate": list(np.arange(0.05, 1, step = 0.1)), 
                          
                          "gbr__n_estimators": list(np.arange(5, 30, step = 5)), 
                          
                          "gbr__max_depth": list(np.arange(15, 30, step = 5)), 
                          
                          "gbr__subsample": list(np.arange(0.5, 1, step = 0.1)), 
                          
                          "gbr__max_features": ["sqrt", 4, 8], 
                          }
# Ridge
grid_rs_ridge= {'ridge__alpha': list(np.arange(0.1, 5, step = 0.2))}

# Lasso
grid_rs_lasso= {'lasso__alpha': list(np.arange(0.1, 5, step = 0.2))}

# KNeighbors
grid_rs_knr = {"knr__n_neighbors": list(np.arange(1, 15, step = 2)), 
                  "knr__weights": ["uniform","distance"]  
                  }

# Linear Suppport Vector Machine 
grid_rs_lsvr={"lsvr__tol":[0.001,0.0001], "lsvr__C": [0.1, 5.0, 50.0]}

# Multi layer perceptron
grid_rs_mlp = {"mlp__hidden_layer_sizes": [(4,),             
                                        (4,4),           
                                        (30,),          
                                        (30,30)],
            
           "mlp__activation": ["relu"], 
            
           "mlp__solver": ["adam"], 
            
           "mlp__alpha": [0.0, 0.1], 
            
           "mlp__validation_fraction": [0.1], 
           "mlp__early_stopping": [True],    
           "mlp__max_iter": [3000],
            
           "mlp__learning_rate_init": list(np.arange(0.001, 0.1, step = 0.01)) 
           }

# XGBRegressor

grid_rs_xgr = {'xgr__max_depth': list(np.arange(1, 10, step = 1)),
            'xgr__learning_rate': [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3],
            'xgr__n_estimators': list(np.arange(50, 200, step = 20))
            }

# %%
rs_dtr = RandomizedSearchCV(dtr, 
                    grid_rs_dtr,
                    n_iter = 20, 
                    cv=5, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)
rs_rfr = RandomizedSearchCV(rfr, 
                    grid_rs_rfr,
                    n_iter = 20, 
                    cv=5, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)

rs_gbr = RandomizedSearchCV(gbr, 
                    grid_rs_gbr,
                    n_iter = 20, 
                    cv=5, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)

rs_ridge = RandomizedSearchCV(ridge, 
                    grid_rs_ridge,
                    n_iter = 20, 
                    cv=5, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)

rs_lasso = RandomizedSearchCV(lasso, 
                    grid_rs_lasso,
                    n_iter = 20, 
                    cv=3, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)

rs_knr = RandomizedSearchCV(knr, 
                    grid_rs_knr,
                    n_iter = 20, 
                    cv=5, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)

rs_mlp = RandomizedSearchCV(mlp,
                      grid_rs_mlp,
                      n_iter = 20,
                      cv=5,
                      scoring='neg_mean_absolute_error',
                      verbose=1,
                      n_jobs=-1)

rs_lsvr = RandomizedSearchCV(lsvr,
                    grid_rs_lsvr,
                    n_iter = 20,
                    cv=5, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)

rs_xgr = RandomizedSearchCV(xgr, 
                    grid_rs_xgr,
                    n_iter = 20, 
                    cv=5, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)
rs_lr = GridSearchCV(lr,
                    param_grid={},
                    cv=10, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)

# %% [markdown]
# Se incluye tambien la regresión lineal, teniendo en cuenta que no tiene hiperparámetros

# %%
all_rs_searchs = {"rs_dtr":rs_dtr,
                    "rs_rfr":rs_rfr,
                    "rs_gbr":rs_gbr,
                    "rs_ridge":rs_ridge,
                    "rs_lasso":rs_lasso,
                    "rs_knr":rs_knr,
                    "rs_lsvr": rs_lsvr,
                    "rs_mlp":rs_mlp,
                    "rs_xgr": rs_xgr,
                    "rs_lr": rs_lr
                    }

# %% [markdown]
# #### Entrenamiento de los modelos

# %% [markdown]
# Se procede a entrenar los modelos para el RandomSearch previsto

# %%
for nombre, grid_search in all_rs_searchs.items():
    start = time.time()
    print("Haciendo Random Search de %s..." % nombre)
    grid_search.fit(X_train, y_train)
    stop = time.time()
    print(f"Tiempo de entrenamiento: {stop - start} s")
# Out:
# Haciendo Random Search de rs_dtr...
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_search.py:292: UserWarning:
#
# The total space of parameters 9 is smaller than n_iter=20. Running 9 iterations. For exhaustive searches, use GridSearchCV.
# Tiempo de entrenamiento: 4.47147011756897 s
# Haciendo Random Search de rs_rfr...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Tiempo de entrenamiento: 61.99264574050903 s
# Haciendo Random Search de rs_gbr...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
#
#
# 30 fits failed out of a total of 100.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/pipeline.py", line 394, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_gb.py", line 586, in fit
#     n_stages = self._fit_stages(
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_gb.py", line 663, in _fit_stages
#     raw_predictions = self._fit_stage(
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_gb.py", line 246, in _fit_stage
#     tree.fit(X, residual, sample_weight=sample_weight, check_input=False)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/tree/_classes.py", line 1315, in fit
#     super().fit(
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/tree/_classes.py", line 308, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_search.py:969: UserWarning:
#
# One or more of the test scores are non-finite: [-10290.2079488  -10633.08636682             nan  -7995.94998929
#   -9920.96058921             nan  -9542.79750049             nan
#   -6982.86563804  -7946.87409463             nan  -7971.67780191
#   -8805.38098068  -7190.04040383  -8534.1896058              nan
#              nan  -7757.6043925   -8768.39043772  -8602.57949277]
# Tiempo de entrenamiento: 21.919559478759766 s
# Haciendo Random Search de rs_ridge...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Tiempo de entrenamiento: 3.9958441257476807 s
# Haciendo Random Search de rs_lasso...
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Tiempo de entrenamiento: 2.4715447425842285 s
# Haciendo Random Search de rs_knr...
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_search.py:292: UserWarning:
#
# The total space of parameters 14 is smaller than n_iter=20. Running 14 iterations. For exhaustive searches, use GridSearchCV.
# Tiempo de entrenamiento: 4.203562021255493 s
# Haciendo Random Search de rs_lsvr...
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_search.py:292: UserWarning:
#
# The total space of parameters 6 is smaller than n_iter=20. Running 6 iterations. For exhaustive searches, use GridSearchCV.
# Tiempo de entrenamiento: 1.3909575939178467 s
# Haciendo Random Search de rs_mlp...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Tiempo de entrenamiento: 488.66334414482117 s
# Haciendo Random Search de rs_xgr...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [21:24:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Tiempo de entrenamiento: 42.55880355834961 s
# Haciendo Random Search de rs_lr...
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Tiempo de entrenamiento: 0.6159589290618896 s

# %% [markdown]
# Se evaluan el desempeño de los modelos tras usar RandomSearch, obteniendo la mejor puntuación de cada modelo. Para eso, hacemos pares modelo-puntuación y lo ordenamos (haciendo uso de un dataframe)

# %% [markdown]
# #### Desempeño de los modelos

# %%
best_score_rs = [(nombre_modelo, grid_search.best_score_)
                                  for nombre_modelo, grid_search           
                                  in all_rs_searchs.items()]

best_score_rs_df = pd.DataFrame(best_score_rs, 
                                columns=["RandomSearchCV", "Best score"]).sort_values(by="Best score", ascending=False)

best_score_rs_df
# Out:
#   RandomSearchCV    Best score
# 1         rs_rfr  -6487.933817
# 8         rs_xgr  -6785.500588
# 5         rs_knr  -6953.127359
# 2         rs_gbr  -6982.865638
# 0         rs_dtr  -7129.679443
# 7         rs_mlp  -8285.010648
# 6        rs_lsvr -10052.225621
# 9          rs_lr -18924.489288
# 3       rs_ridge -18924.542481
# 4       rs_lasso -18928.141987

# %% [markdown]
# Seleccionamos los 5 mejores modelos, a los que le haremos un GridSearch para afinar más los hiperparámetros. Para eso, vemos los valores de los mejores hiperparámetros obtenidos y vamos creando las mallas (grid) donde afinar los valores

# %% [markdown]
# ##### RFR

# %% [markdown]
# Repetimos el mismo procedimiento que con el XGR

# %%
best_randomsearch = all_rs_searchs["rs_rfr"]
# Save the model best model
best_pipeline = best_randomsearch.best_estimator_
best_pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('prep',
#    ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                     ['Año', 'Kilometraje', 'Potencia', 'Fotos'])])),
#   ('rfr',
#    RandomForestRegressor(max_depth=20, max_features='sqrt', n_estimators=70))],
#  'verbose': False,
#  'prep': ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                   ['Año', 'Kilometraje', 'Potencia', 'Fotos'])]),
#  'rfr': RandomForestRegressor(max_depth=20, max_features='sqrt', n_estimators=70),
#  'prep__n_jobs': None,
#  'prep__remainder': 'drop',
#  'prep__sparse_threshold': 0.3,
#  'prep__transformer_weights': None,
#  'prep__transformers': [('rescale numeric',
#    StandardScaler(),
#    ['Año', 'Kilometraje', 'Potencia', 'Fotos'])],
#  'prep__verbose': False,
#  'prep__verbose_feature_names_out': True,
#  'prep__rescale numeric': StandardScaler(),
#  'prep__rescale numeric__copy': True,
#  'prep__rescale numeric__with_mean': True,
#  'prep__rescale numeric__with_std': True,
#  'rfr__bootstrap': True,
#  'rfr__ccp_alpha': 0.0,
#  'rfr__criterion': 'squared_error',
#  'rfr__max_depth': 20,
#  'rfr__max_features': 'sqrt',
#  'rfr__max_leaf_nodes': None,
#  'rfr__max_samples': None,
#  'rfr__min_impurity_decrease': 0.0,
#  'rfr__min_samples_leaf': 1,
#  'rfr__min_samples_split': 2,
#  'rfr__min_weight_fraction_leaf': 0.0,
#  'rfr__n_estimators': 70,
#  'rfr__n_jobs': None,
#  'rfr__oob_score': False,
#  'rfr__random_state': None,
#  'rfr__verbose': 0,
#  'rfr__warm_start': False}

# %%
mse = mean_squared_error(y_true=y_test, y_pred=best_pipeline.predict(X_test))
mae = mean_absolute_error(y_true=y_test,y_pred=best_pipeline.predict(X_test))
rmse = np.sqrt(mse)

print("MSE: " + str(mse))
print("MAE: " +  str(mae))
print("RMSE: " +  str(rmse))
# Out:
# MSE: 8819375065.671465
# MAE: 7225.175095706182
# RMSE: 93911.52786357734

# %%
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, rs_rfr)

# %%
grid_rfr = {"rfr__n_estimators": [70, 75, 80, 85, 90], 
            "rfr__max_depth": [40, 45, 50, 55, 60], 
            "rfr__max_features": ["sqrt", 3] 
                     }

# %% [markdown]
# ##### XGR

# %% [markdown]
# Vemos las métricas de error y lo bueno que es el ajuste con los hiperparámetros resultantes del RandomSearch

# %%
best_randomsearch = all_rs_searchs["rs_xgr"]
# Save the model best model
best_pipeline = best_randomsearch.best_estimator_
best_pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('prep',
#    ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                     ['Año', 'Kilometraje', 'Potencia', 'Fotos'])])),
#   ('xgr', XGBRegressor(max_depth=8, n_estimators=90))],
#  'verbose': False,
#  'prep': ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                   ['Año', 'Kilometraje', 'Potencia', 'Fotos'])]),
#  'xgr': XGBRegressor(max_depth=8, n_estimators=90),
#  'prep__n_jobs': None,
#  'prep__remainder': 'drop',
#  'prep__sparse_threshold': 0.3,
#  'prep__transformer_weights': None,
#  'prep__transformers': [('rescale numeric',
#    StandardScaler(),
#    ['Año', 'Kilometraje', 'Potencia', 'Fotos'])],
#  'prep__verbose': False,
#  'prep__verbose_feature_names_out': True,
#  'prep__rescale numeric': StandardScaler(),
#  'prep__rescale numeric__copy': True,
#  'prep__rescale numeric__with_mean': True,
#  'prep__rescale numeric__with_std': True,
#  'xgr__base_score': 0.5,
#  'xgr__booster': 'gbtree',
#  'xgr__colsample_bylevel': 1,
#  'xgr__colsample_bynode': 1,
#  'xgr__colsample_bytree': 1,
#  'xgr__gamma': 0,
#  'xgr__importance_type': 'gain',
#  'xgr__learning_rate': 0.1,
#  'xgr__max_delta_step': 0,
#  'xgr__max_depth': 8,
#  'xgr__min_child_weight': 1,
#  'xgr__missing': None,
#  'xgr__n_estimators': 90,
#  'xgr__n_jobs': 1,
#  'xgr__nthread': None,
#  'xgr__objective': 'reg:linear',
#  'xgr__random_state': 0,
#  'xgr__reg_alpha': 0,
#  'xgr__reg_lambda': 1,
#  'xgr__scale_pos_weight': 1,
#  'xgr__seed': None,
#  'xgr__silent': None,
#  'xgr__subsample': 1,
#  'xgr__verbosity': 1}

# %%
mse = mean_squared_error(y_true=y_test, y_pred=best_pipeline.predict(X_test))
mae = mean_absolute_error(y_true=y_test,y_pred=best_pipeline.predict(X_test))
rmse = np.sqrt(mse)

print("MSE: " + str(mse))
print("MAE: " +  str(mae))
print("RMSE: " +  str(rmse))
# Out:
# MSE: 9397249937.06925
# MAE: 7704.014827231591
# RMSE: 96939.4137442003

# %%
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, rs_xgr)

# %% [markdown]
# A partir de los mejores valores del RandomSearch, fijamos la malla para el GridSearch que se usará afinando parámetros

# %%
grid_xgr = {'xgr__max_depth': [5, 6, 7, 8, 9],
            'xgr__learning_rate': [0.15, 0.2, 0.25],
            'xgr__n_estimators': [250, 270, 290, 310, 330, 350, 370]
            }

# %% [markdown]
# ##### KNR

# %% [markdown]
# Repetimos el mismo procedimiento de antes

# %%
best_randomsearch = all_rs_searchs["rs_knr"]
# Save the model best model
best_pipeline = best_randomsearch.best_estimator_
best_pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('prep',
#    ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                     ['Año', 'Kilometraje', 'Potencia', 'Fotos'])])),
#   ('knr', KNeighborsRegressor(n_neighbors=13, weights='distance'))],
#  'verbose': False,
#  'prep': ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                   ['Año', 'Kilometraje', 'Potencia', 'Fotos'])]),
#  'knr': KNeighborsRegressor(n_neighbors=13, weights='distance'),
#  'prep__n_jobs': None,
#  'prep__remainder': 'drop',
#  'prep__sparse_threshold': 0.3,
#  'prep__transformer_weights': None,
#  'prep__transformers': [('rescale numeric',
#    StandardScaler(),
#    ['Año', 'Kilometraje', 'Potencia', 'Fotos'])],
#  'prep__verbose': False,
#  'prep__verbose_feature_names_out': True,
#  'prep__rescale numeric': StandardScaler(),
#  'prep__rescale numeric__copy': True,
#  'prep__rescale numeric__with_mean': True,
#  'prep__rescale numeric__with_std': True,
#  'knr__algorithm': 'auto',
#  'knr__leaf_size': 30,
#  'knr__metric': 'minkowski',
#  'knr__metric_params': None,
#  'knr__n_jobs': None,
#  'knr__n_neighbors': 13,
#  'knr__p': 2,
#  'knr__weights': 'distance'}

# %%
mse = mean_squared_error(y_true=y_test, y_pred=best_pipeline.predict(X_test))
mae = mean_absolute_error(y_true=y_test,y_pred=best_pipeline.predict(X_test))
rmse = np.sqrt(mse)

print("MSE: " + str(mse))
print("MAE: " +  str(mae))
print("RMSE: " +  str(rmse))
# Out:
# MSE: 7323092983.83496
# MAE: 7445.504773908429
# RMSE: 85575.0722105156

# %%
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, rs_knr)

# %% [markdown]
# A partir de los mejores valores del RandomSearch, fijamos la malla para el GridSearch que se usará afinando parámetros

# %%
grid_knr = {"knr__n_neighbors": list(np.arange(5, 20, step = 1)), 
                  "knr__weights": ["uniform","distance"]  
                  }

# %% [markdown]
# ##### GBR

# %% [markdown]
# Repetimos el mismo procedimiento de antes

# %%
best_randomsearch = all_rs_searchs["rs_gbr"]
# Save the model best model
best_pipeline = best_randomsearch.best_estimator_
best_pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('prep',
#    ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                     ['Año', 'Kilometraje', 'Potencia', 'Fotos'])])),
#   ('gbr',
#    GradientBoostingRegressor(learning_rate=0.25000000000000006, max_depth=20,
#                              max_features='sqrt', n_estimators=25,
#                              subsample=0.7999999999999999))],
#  'verbose': False,
#  'prep': ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                   ['Año', 'Kilometraje', 'Potencia', 'Fotos'])]),
#  'gbr': GradientBoostingRegressor(learning_rate=0.25000000000000006, max_depth=20,
#                            max_features='sqrt', n_estimators=25,
#                            subsample=0.7999999999999999),
#  'prep__n_jobs': None,
#  'prep__remainder': 'drop',
#  'prep__sparse_threshold': 0.3,
#  'prep__transformer_weights': None,
#  'prep__transformers': [('rescale numeric',
#    StandardScaler(),
#    ['Año', 'Kilometraje', 'Potencia', 'Fotos'])],
#  'prep__verbose': False,
#  'prep__verbose_feature_names_out': True,
#  'prep__rescale numeric': StandardScaler(),
#  'prep__rescale numeric__copy': True,
#  'prep__rescale numeric__with_mean': True,
#  'prep__rescale numeric__with_std': True,
#  'gbr__alpha': 0.9,
#  'gbr__ccp_alpha': 0.0,
#  'gbr__criterion': 'friedman_mse',
#  'gbr__init': None,
#  'gbr__learning_rate': 0.25000000000000006,
#  'gbr__loss': 'squared_error',
#  'gbr__max_depth': 20,
#  'gbr__max_features': 'sqrt',
#  'gbr__max_leaf_nodes': None,
#  'gbr__min_impurity_decrease': 0.0,
#  'gbr__min_samples_leaf': 1,
#  'gbr__min_samples_split': 2,
#  'gbr__min_weight_fraction_leaf': 0.0,
#  'gbr__n_estimators': 25,
#  'gbr__n_iter_no_change': None,
#  'gbr__random_state': None,
#  'gbr__subsample': 0.7999999999999999,
#  'gbr__tol': 0.0001,
#  'gbr__validation_fraction': 0.1,
#  'gbr__verbose': 0,
#  'gbr__warm_start': False}

# %%
mse = mean_squared_error(y_true=y_test, y_pred=best_pipeline.predict(X_test))
mae = mean_absolute_error(y_true=y_test,y_pred=best_pipeline.predict(X_test))
rmse = np.sqrt(mse)

print("MSE: " + str(mse))
print("MAE: " +  str(mae))
print("RMSE: " +  str(rmse))
# Out:
# MSE: 7463499127.370521
# MAE: 7535.880041525421
# RMSE: 86391.54546233399

# %%
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, rs_gbr)

# %% [markdown]
# A partir de los mejores valores del RandomSearch, fijamos la malla para el GridSearch que se usará afinando parámetros

# %%
grid_gbr = {"gbr__loss": ["squared_error"],
                "gbr__learning_rate": [0.10, 0.15, 0.2],           
                "gbr__n_estimators": [25, 35, 45], 
                "gbr__max_depth": [11, 12, 13], 
                "gbr__subsample": [0.85, 0.9, 0.95], 
                "gbr__max_features": ['sqrt', 2], 
                }

# %% [markdown]
# ##### DTR

# %% [markdown]
# También se procede igual

# %%
best_randomsearch = all_rs_searchs["rs_dtr"]
# Save the model best model
best_pipeline = best_randomsearch.best_estimator_
best_pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('prep',
#    ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                     ['Año', 'Kilometraje', 'Potencia', 'Fotos'])])),
#   ('dtr', DecisionTreeRegressor(max_depth=12))],
#  'verbose': False,
#  'prep': ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                   ['Año', 'Kilometraje', 'Potencia', 'Fotos'])]),
#  'dtr': DecisionTreeRegressor(max_depth=12),
#  'prep__n_jobs': None,
#  'prep__remainder': 'drop',
#  'prep__sparse_threshold': 0.3,
#  'prep__transformer_weights': None,
#  'prep__transformers': [('rescale numeric',
#    StandardScaler(),
#    ['Año', 'Kilometraje', 'Potencia', 'Fotos'])],
#  'prep__verbose': False,
#  'prep__verbose_feature_names_out': True,
#  'prep__rescale numeric': StandardScaler(),
#  'prep__rescale numeric__copy': True,
#  'prep__rescale numeric__with_mean': True,
#  'prep__rescale numeric__with_std': True,
#  'dtr__ccp_alpha': 0.0,
#  'dtr__criterion': 'squared_error',
#  'dtr__max_depth': 12,
#  'dtr__max_features': None,
#  'dtr__max_leaf_nodes': None,
#  'dtr__min_impurity_decrease': 0.0,
#  'dtr__min_samples_leaf': 1,
#  'dtr__min_samples_split': 2,
#  'dtr__min_weight_fraction_leaf': 0.0,
#  'dtr__random_state': None,
#  'dtr__splitter': 'best'}

# %%
mse = mean_squared_error(y_true=y_test, y_pred=best_pipeline.predict(X_test))
mae = mean_absolute_error(y_true=y_test,y_pred=best_pipeline.predict(X_test))
rmse = np.sqrt(mse)

print("MSE: " + str(mse))
print("MAE: " +  str(mae))
print("RMSE: " +  str(rmse))
# Out:
# MSE: 9227750812.587538
# MAE: 7832.943485836695
# RMSE: 96061.18265245092

# %%
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, rs_dtr)

# %%
grid_dtr = {"dtr__max_depth": list(np.arange(2, 20, step = 1))
           }

# %% [markdown]
# ### Finetuning de hiperparámetros

# %% [markdown]
# Para los 5 mejores modelos, en base a los resultados del RandomSearchCV, se hace un GridSearchCV con el objetivo de afinar los valores de los hiperparámetros

# %%
gs_xgr = GridSearchCV(xgr, 
                    grid_xgr, 
                    cv=5, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)

gs_rfr = GridSearchCV(rfr, 
                    grid_rfr, 
                    cv=5, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)

gs_gbr = GridSearchCV(gbr, 
                    grid_gbr, 
                    cv=5, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)

gs_knr = GridSearchCV(knr, 
                    grid_knr, 
                    cv=5, 
                    scoring="neg_mean_absolute_error", 
                    verbose=1, 
                    n_jobs=-1)

gs_dtr = GridSearchCV(dtr,
                      grid_dtr,
                      cv=5,
                      scoring='neg_mean_absolute_error',
                      verbose=1,
                      n_jobs=-1)

# %%
all_gs_searchs = {"gs_xgr": gs_xgr,
                  "gs_rfr": gs_rfr,
                  "gs_gbr": gs_gbr,
                  "gs_knr": gs_knr,
                    "gs_dtr": gs_dtr
                    }

# %% [markdown]
# #### Entrenamiento de los modelos

# %%
for nombre, grid_search in all_gs_searchs.items():
    start = time.time()
    print("Haciendo Grid Search de %s..." % nombre)
    grid_search.fit(X_train, y_train)
    stop = time.time()
    print(f"Tiempo de entrenamiento: {stop - start} s")
# Out:
# Haciendo Grid Search de gs_xgr...
# Fitting 5 folds for each of 105 candidates, totalling 525 fits
# [21:35:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Tiempo de entrenamiento: 669.042986869812 s
# Haciendo Grid Search de gs_rfr...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# /usr/local/lib/python3.8/dist-packages/joblib/externals/loky/process_executor.py:700: UserWarning:
#
# A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
# Tiempo de entrenamiento: 241.09434056282043 s
# Haciendo Grid Search de gs_gbr...
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# Tiempo de entrenamiento: 248.6094651222229 s
# Haciendo Grid Search de gs_knr...
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Tiempo de entrenamiento: 9.57059359550476 s
# Haciendo Grid Search de gs_dtr...
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Tiempo de entrenamiento: 4.8657402992248535 s

# %% [markdown]
# #### Desempeño de los modelos

# %% [markdown]
# Evaluamos las métricas con el conjunto de test

# %% [markdown]
# ##### RFR

# %%
best_randomsearch = all_gs_searchs["gs_rfr"]
best_pipeline = best_randomsearch.best_estimator_

# %%
best_pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('prep',
#    ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                     ['Año', 'Kilometraje', 'Potencia', 'Fotos'])])),
#   ('rfr',
#    RandomForestRegressor(max_depth=40, max_features='sqrt', n_estimators=90))],
#  'verbose': False,
#  'prep': ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                   ['Año', 'Kilometraje', 'Potencia', 'Fotos'])]),
#  'rfr': RandomForestRegressor(max_depth=40, max_features='sqrt', n_estimators=90),
#  'prep__n_jobs': None,
#  'prep__remainder': 'drop',
#  'prep__sparse_threshold': 0.3,
#  'prep__transformer_weights': None,
#  'prep__transformers': [('rescale numeric',
#    StandardScaler(),
#    ['Año', 'Kilometraje', 'Potencia', 'Fotos'])],
#  'prep__verbose': False,
#  'prep__verbose_feature_names_out': True,
#  'prep__rescale numeric': StandardScaler(),
#  'prep__rescale numeric__copy': True,
#  'prep__rescale numeric__with_mean': True,
#  'prep__rescale numeric__with_std': True,
#  'rfr__bootstrap': True,
#  'rfr__ccp_alpha': 0.0,
#  'rfr__criterion': 'squared_error',
#  'rfr__max_depth': 40,
#  'rfr__max_features': 'sqrt',
#  'rfr__max_leaf_nodes': None,
#  'rfr__max_samples': None,
#  'rfr__min_impurity_decrease': 0.0,
#  'rfr__min_samples_leaf': 1,
#  'rfr__min_samples_split': 2,
#  'rfr__min_weight_fraction_leaf': 0.0,
#  'rfr__n_estimators': 90,
#  'rfr__n_jobs': None,
#  'rfr__oob_score': False,
#  'rfr__random_state': None,
#  'rfr__verbose': 0,
#  'rfr__warm_start': False}

# %%
mse = mean_squared_error(y_true=y_test, y_pred=best_pipeline.predict(X_test))
mae = mean_absolute_error(y_true=y_test,y_pred=best_pipeline.predict(X_test))
rmse = np.sqrt(mse)

print("MSE: " + str(mse))
print("MAE: " +  str(mae))
print("RMSE: " +  str(rmse))
# Out:
# MSE: 8285480336.493253
# MAE: 7186.108040388151
# RMSE: 91024.61390466455

# %%
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, gs_rfr)

# %%
sns.set(style="white")
plt.figure(figsize=(20,8))
xx = np.stack(i for i in range(y_test.shape[0]))
plt.plot(xx, y_test, c='r', label='Datos', marker='o')
plt.plot(xx, best_pipeline.predict(X_test), c='g', label='Predicción', marker='o')
plt.axis('tight')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3249: FutureWarning:
#
# arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.

# %% [markdown]
# ##### XGR

# %%
best_randomsearch = all_gs_searchs["gs_xgr"]
best_pipeline = best_randomsearch.best_estimator_

# %%
best_pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('prep',
#    ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                     ['Año', 'Kilometraje', 'Potencia', 'Fotos'])])),
#   ('xgr', XGBRegressor(learning_rate=0.25, max_depth=7, n_estimators=250))],
#  'verbose': False,
#  'prep': ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                   ['Año', 'Kilometraje', 'Potencia', 'Fotos'])]),
#  'xgr': XGBRegressor(learning_rate=0.25, max_depth=7, n_estimators=250),
#  'prep__n_jobs': None,
#  'prep__remainder': 'drop',
#  'prep__sparse_threshold': 0.3,
#  'prep__transformer_weights': None,
#  'prep__transformers': [('rescale numeric',
#    StandardScaler(),
#    ['Año', 'Kilometraje', 'Potencia', 'Fotos'])],
#  'prep__verbose': False,
#  'prep__verbose_feature_names_out': True,
#  'prep__rescale numeric': StandardScaler(),
#  'prep__rescale numeric__copy': True,
#  'prep__rescale numeric__with_mean': True,
#  'prep__rescale numeric__with_std': True,
#  'xgr__base_score': 0.5,
#  'xgr__booster': 'gbtree',
#  'xgr__colsample_bylevel': 1,
#  'xgr__colsample_bynode': 1,
#  'xgr__colsample_bytree': 1,
#  'xgr__gamma': 0,
#  'xgr__importance_type': 'gain',
#  'xgr__learning_rate': 0.25,
#  'xgr__max_delta_step': 0,
#  'xgr__max_depth': 7,
#  'xgr__min_child_weight': 1,
#  'xgr__missing': None,
#  'xgr__n_estimators': 250,
#  'xgr__n_jobs': 1,
#  'xgr__nthread': None,
#  'xgr__objective': 'reg:linear',
#  'xgr__random_state': 0,
#  'xgr__reg_alpha': 0,
#  'xgr__reg_lambda': 1,
#  'xgr__scale_pos_weight': 1,
#  'xgr__seed': None,
#  'xgr__silent': None,
#  'xgr__subsample': 1,
#  'xgr__verbosity': 1}

# %%
mse = mean_squared_error(y_true=y_test, y_pred=best_pipeline.predict(X_test))
mae = mean_absolute_error(y_true=y_test,y_pred=best_pipeline.predict(X_test))
rmse = np.sqrt(mse)

print("MSE: " + str(mse))
print("MAE: " +  str(mae))
print("RMSE: " +  str(rmse))
# Out:
# MSE: 8826169558.580746
# MAE: 7210.018983446588
# RMSE: 93947.69586626776

# %%
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, gs_xgr)

# %%
sns.set(style="white")
plt.figure(figsize=(20,8))
xx = np.stack(i for i in range(y_test.shape[0]))
plt.plot(xx, y_test, c='r', label='Datos', marker='o')
plt.plot(xx, best_pipeline.predict(X_test), c='g', label='Predicción', marker='o')
plt.axis('tight')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3249: FutureWarning:
#
# arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.

# %% [markdown]
# ##### KBR

# %%
best_randomsearch = all_gs_searchs["gs_knr"]
best_pipeline = best_randomsearch.best_estimator_

# %%
best_pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('prep',
#    ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                     ['Año', 'Kilometraje', 'Potencia', 'Fotos'])])),
#   ('knr', KNeighborsRegressor(n_neighbors=19, weights='distance'))],
#  'verbose': False,
#  'prep': ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                   ['Año', 'Kilometraje', 'Potencia', 'Fotos'])]),
#  'knr': KNeighborsRegressor(n_neighbors=19, weights='distance'),
#  'prep__n_jobs': None,
#  'prep__remainder': 'drop',
#  'prep__sparse_threshold': 0.3,
#  'prep__transformer_weights': None,
#  'prep__transformers': [('rescale numeric',
#    StandardScaler(),
#    ['Año', 'Kilometraje', 'Potencia', 'Fotos'])],
#  'prep__verbose': False,
#  'prep__verbose_feature_names_out': True,
#  'prep__rescale numeric': StandardScaler(),
#  'prep__rescale numeric__copy': True,
#  'prep__rescale numeric__with_mean': True,
#  'prep__rescale numeric__with_std': True,
#  'knr__algorithm': 'auto',
#  'knr__leaf_size': 30,
#  'knr__metric': 'minkowski',
#  'knr__metric_params': None,
#  'knr__n_jobs': None,
#  'knr__n_neighbors': 19,
#  'knr__p': 2,
#  'knr__weights': 'distance'}

# %%
mse = mean_squared_error(y_true=y_test, y_pred=best_pipeline.predict(X_test))
mae = mean_absolute_error(y_true=y_test,y_pred=best_pipeline.predict(X_test))
rmse = np.sqrt(mse)

print("MSE: " + str(mse))
print("MAE: " +  str(mae))
print("RMSE: " +  str(rmse))
# Out:
# MSE: 7376883630.585426
# MAE: 7480.534425396513
# RMSE: 85888.78640768786

# %%
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, gs_knr)

# %%
sns.set(style="white")
plt.figure(figsize=(20,8))
xx = np.stack(i for i in range(y_test.shape[0]))
plt.plot(xx, y_test, c='r', label='Datos', marker='o')
plt.plot(xx, best_pipeline.predict(X_test), c='g', label='Predicción', marker='o')
plt.axis('tight')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3249: FutureWarning:
#
# arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.

# %% [markdown]
# ##### GBR

# %%
best_randomsearch = all_gs_searchs["gs_gbr"]
best_pipeline = best_randomsearch.best_estimator_

# %%
best_pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('prep',
#    ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                     ['Año', 'Kilometraje', 'Potencia', 'Fotos'])])),
#   ('gbr',
#    GradientBoostingRegressor(max_depth=13, max_features='sqrt', n_estimators=35,
#                              subsample=0.9))],
#  'verbose': False,
#  'prep': ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                   ['Año', 'Kilometraje', 'Potencia', 'Fotos'])]),
#  'gbr': GradientBoostingRegressor(max_depth=13, max_features='sqrt', n_estimators=35,
#                            subsample=0.9),
#  'prep__n_jobs': None,
#  'prep__remainder': 'drop',
#  'prep__sparse_threshold': 0.3,
#  'prep__transformer_weights': None,
#  'prep__transformers': [('rescale numeric',
#    StandardScaler(),
#    ['Año', 'Kilometraje', 'Potencia', 'Fotos'])],
#  'prep__verbose': False,
#  'prep__verbose_feature_names_out': True,
#  'prep__rescale numeric': StandardScaler(),
#  'prep__rescale numeric__copy': True,
#  'prep__rescale numeric__with_mean': True,
#  'prep__rescale numeric__with_std': True,
#  'gbr__alpha': 0.9,
#  'gbr__ccp_alpha': 0.0,
#  'gbr__criterion': 'friedman_mse',
#  'gbr__init': None,
#  'gbr__learning_rate': 0.1,
#  'gbr__loss': 'squared_error',
#  'gbr__max_depth': 13,
#  'gbr__max_features': 'sqrt',
#  'gbr__max_leaf_nodes': None,
#  'gbr__min_impurity_decrease': 0.0,
#  'gbr__min_samples_leaf': 1,
#  'gbr__min_samples_split': 2,
#  'gbr__min_weight_fraction_leaf': 0.0,
#  'gbr__n_estimators': 35,
#  'gbr__n_iter_no_change': None,
#  'gbr__random_state': None,
#  'gbr__subsample': 0.9,
#  'gbr__tol': 0.0001,
#  'gbr__validation_fraction': 0.1,
#  'gbr__verbose': 0,
#  'gbr__warm_start': False}

# %%
mse = mean_squared_error(y_true=y_test, y_pred=best_pipeline.predict(X_test))
mae = mean_absolute_error(y_true=y_test,y_pred=best_pipeline.predict(X_test))
rmse = np.sqrt(mse)

print("MSE: " + str(mse))
print("MAE: " +  str(mae))
print("RMSE: " +  str(rmse))
# Out:
# MSE: 7785920983.570169
# MAE: 7001.4929701091005
# RMSE: 88237.86592824063

# %%
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, gs_gbr)

# %%
sns.set(style="white")
plt.figure(figsize=(20,8))
xx = np.stack(i for i in range(y_test.shape[0]))
plt.plot(xx, y_test, c='r', label='Datos', marker='o')
plt.plot(xx, best_pipeline.predict(X_test), c='g', label='Predicción', marker='o')
plt.axis('tight')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3249: FutureWarning:
#
# arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.

# %% [markdown]
# ##### DTR

# %%
best_randomsearch = all_gs_searchs["gs_dtr"]
best_pipeline = best_randomsearch.best_estimator_

# %%
best_pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('prep',
#    ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                     ['Año', 'Kilometraje', 'Potencia', 'Fotos'])])),
#   ('dtr', DecisionTreeRegressor(max_depth=14))],
#  'verbose': False,
#  'prep': ColumnTransformer(transformers=[('rescale numeric', StandardScaler(),
#                                   ['Año', 'Kilometraje', 'Potencia', 'Fotos'])]),
#  'dtr': DecisionTreeRegressor(max_depth=14),
#  'prep__n_jobs': None,
#  'prep__remainder': 'drop',
#  'prep__sparse_threshold': 0.3,
#  'prep__transformer_weights': None,
#  'prep__transformers': [('rescale numeric',
#    StandardScaler(),
#    ['Año', 'Kilometraje', 'Potencia', 'Fotos'])],
#  'prep__verbose': False,
#  'prep__verbose_feature_names_out': True,
#  'prep__rescale numeric': StandardScaler(),
#  'prep__rescale numeric__copy': True,
#  'prep__rescale numeric__with_mean': True,
#  'prep__rescale numeric__with_std': True,
#  'dtr__ccp_alpha': 0.0,
#  'dtr__criterion': 'squared_error',
#  'dtr__max_depth': 14,
#  'dtr__max_features': None,
#  'dtr__max_leaf_nodes': None,
#  'dtr__min_impurity_decrease': 0.0,
#  'dtr__min_samples_leaf': 1,
#  'dtr__min_samples_split': 2,
#  'dtr__min_weight_fraction_leaf': 0.0,
#  'dtr__random_state': None,
#  'dtr__splitter': 'best'}

# %%
mse = mean_squared_error(y_true=y_test, y_pred=best_pipeline.predict(X_test))
mae = mean_absolute_error(y_true=y_test,y_pred=best_pipeline.predict(X_test))
rmse = np.sqrt(mse)

print("MSE: " + str(mse))
print("MAE: " +  str(mae))
print("RMSE: " +  str(rmse))
# Out:
# MSE: 9203486974.929613
# MAE: 7948.14643511801
# RMSE: 95934.80585756982

# %%
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, gs_dtr)

# %%
sns.set(style="white")
plt.figure(figsize=(20,8))
xx = np.stack(i for i in range(y_test.shape[0]))
plt.plot(xx, y_test, c='r', label='Datos', marker='o')
plt.plot(xx, best_pipeline.predict(X_test), c='g', label='Predicción', marker='o')
plt.axis('tight')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3249: FutureWarning:
#
# arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
